# %%
import pandas as pd
import yfinance as yf

# %% [markdown]
# # Part 1: Convert to Text for Each Token

# %% [markdown]
# ## BTC

# %%
btc = pd.read_csv("tokens/BTC/btc_full.csv", parse_dates=["timestamp"])

# Delete the first few rows where there is NA cells
btc = btc.iloc[24:].reset_index(drop=True)

btc.columns
# Out:
# Index(['timestamp', 'close_price', 'volume_base', 'volume_quote',
#        'transaction_count', 'total_value_transferred_btc', 'avg_fee_btc',
#        'total_size_used_mb', 'unique_active_wallets', 'market_cap', 'ma_6',
#        'ma_24', 'ma_crossover_signal', 'ma_crossover_description', 'ema_12',
#        'ema_26', 'macd', 'macd_signal', 'macd_hist', 'macd_crossover_signal',
#        'macd_crossover_description', 'txn_ratio', 'txn_ratio_description',
#        'bb_mid', 'bb_std', 'bb_upper', 'bb_lower', 'bb_position',
#        'price_change_pct', 'price_movement'],
#       dtype='object')

# %%
btc["text"] = btc.apply(
    lambda row: (
        f"Price: {row['close_price']} USD\n"
        f"Price change compared to last hour: {row['price_change_pct'] * 100:+.4f}% ({row['price_movement']})\n"
        f"Volume: {row['volume_base']:.4f} BTC\n"
        f"Market cap: {row['market_cap']:,.2f} USD\n"
        f"Trend signal: {row['ma_crossover_description']}\n"
        f"Momentum signal: {row['macd_crossover_description']}\n"
        f"Price regime (Bollinger Bands): {row['bb_position']}\n"
        f"On-chain activity:\n"
        f"- {row['transaction_count']} transactions → {row['txn_ratio_description']} (txn ratio = {row['txn_ratio']}, compared to 24h average)\n"
        f"- {row['unique_active_wallets']} active wallets\n"
        f"- {row['total_value_transferred_btc']} BTC transferred\n"
        f"- Average transaction fee: {row['avg_fee_btc']:.8f}\n"
        f"- {row['total_size_used_mb']} MB block size used"
    ),
    axis=1
)

# %%
btc.to_csv("BTC/btc_with_text.csv", index=False)

# %% [markdown]
# ## ETH

# %%
eth = pd.read_csv("tokens/ETH/eth_full.csv", parse_dates=["timestamp"])
eth = eth.iloc[24:].reset_index(drop=True)

# %%
eth.columns
# Out:
# Index(['timestamp', 'close_price', 'volume_base', 'volume_quote',
#        'transaction_count', 'total_value_transferred_eth',
#        'unique_active_wallets', 'avg_gas_price_gwei', 'total_gas_used',
#        'market_cap', 'ma_6', 'ma_24', 'ma_crossover_signal',
#        'ma_crossover_description', 'ema_12', 'ema_26', 'macd', 'macd_signal',
#        'macd_hist', 'macd_crossover_signal', 'macd_crossover_description',
#        'txn_ratio', 'txn_ratio_description', 'bb_mid', 'bb_std', 'bb_upper',
#        'bb_lower', 'bb_position', 'price_change_pct', 'price_movement'],
#       dtype='object')

# %%
eth["text"] = eth.apply(
    lambda row: (
        f"Price: {row['close_price']} USD\n"
        f"Price change compared to last hour: {row['price_change_pct'] * 100:+.4f}% ({row['price_movement']})\n"
        f"Volume: {row['volume_base']:.4f} ETH\n"
        f"Market cap: {row['market_cap']:,.2f} USD\n"
        f"Trend signal: {row['ma_crossover_description']}\n"
        f"Momentum signal: {row['macd_crossover_description']}\n"
        f"Price regime (Bollinger Bands): {row['bb_position']}\n"
        f"On-chain activity:\n"
        f"- {row['transaction_count']} transactions → {row['txn_ratio_description']} (txn ratio = {row['txn_ratio']}, compared to 24h average)\n"
        f"- {row['unique_active_wallets']} active wallets\n"
        f"- {row['total_value_transferred_eth']} ETH transferred\n"
        f"- {row['avg_gas_price_gwei']} Gwei average gas price\n"
        f"- {row['total_gas_used']:,.0f} total gas used"
    ),
    axis=1
)

# %%
eth.to_csv("ETH/eth_with_text.csv", index=False)

# %% [markdown]
# ## SOL

# %%
sol = pd.read_csv("tokens/SOL/sol_full.csv", parse_dates=["timestamp"])
sol = sol.iloc[24:].reset_index(drop=True)
sol.head()
# Out:
#             timestamp  close_price  volume_base  volume_quote  \
# 0 2024-05-02 00:00:00     131.4696  739088.8957   97971114.19
# 1 2024-05-02 01:00:00     129.6897  612510.1719   79864504.21
# 2 2024-05-02 02:00:00     129.6112  539810.0675   69934077.55
# 3 2024-05-02 03:00:00     130.0905  411643.4165   53646068.35
# 4 2024-05-02 04:00:00     129.5669  442239.6301   57617701.05
#
#    transaction_count  successful_transaction_count  total_fee_sol  \
# 0            9021681                       7061930       280.9976
# 1            8822319                       6868772       243.0346
# 2            9235352                       7203347       238.7772
# 3            9284207                       7307339       247.4921
# 4            9015569                       6970857       230.0827
#
#    avg_fee_sol    market_cap      ma_6  ...  \
# 0     0.000031  6.029255e+10  132.3795  ...
# 1     0.000028  5.868043e+10  132.3830  ...
# 2     0.000026  5.822609e+10  132.0229  ...
# 3     0.000027  5.805589e+10  131.4748  ...
# 4     0.000026  5.821185e+10  130.8429  ...
#
#                           macd_crossover_description  txn_ratio  \
# 0  MACD (12h vs 26h EMA) is above signal line → b...     1.0692
# 1  MACD (12h vs 26h EMA) is above signal line → b...     1.0480
# 2  MACD (12h vs 26h EMA) is above signal line → b...     1.0928
# 3  MACD (12h vs 26h EMA) is above signal line → b...     1.0997
# 4  MACD (12h vs 26h EMA) is below signal line → n...     1.0691
#
#   txn_ratio_description      bb_mid    bb_std  bb_upper  bb_lower  \
# 0       normal activity  126.421300  4.962783  136.3469  116.4957
# 1       normal activity  126.651685  5.004115  136.6599  116.6435
# 2       normal activity  126.990930  4.960930  136.9128  117.0691
# 3       normal activity  127.470300  4.760170  136.9906  117.9500
# 4       normal activity  127.893660  4.534961  136.9636  118.8237
#
#                   bb_position  price_change_pct         price_movement
# 0  within band (normal range)         -0.023473   significant decrease
# 1  within band (normal range)         -0.013538   significant decrease
# 2  within band (normal range)         -0.000605  no significant change
# 3  within band (normal range)          0.003698        slight increase
# 4  within band (normal range)         -0.004025        slight decrease
#
# [5 rows x 29 columns]

# %%
sol.columns
# Out:
# Index(['timestamp', 'close_price', 'volume_base', 'volume_quote',
#        'transaction_count', 'successful_transaction_count', 'total_fee_sol',
#        'avg_fee_sol', 'market_cap', 'ma_6', 'ma_24', 'ma_crossover_signal',
#        'ma_crossover_description', 'ema_12', 'ema_26', 'macd', 'macd_signal',
#        'macd_hist', 'macd_crossover_signal', 'macd_crossover_description',
#        'txn_ratio', 'txn_ratio_description', 'bb_mid', 'bb_std', 'bb_upper',
#        'bb_lower', 'bb_position', 'price_change_pct', 'price_movement'],
#       dtype='object')

# %%
sol["text"] = sol.apply(
    lambda row: (
        f"Price: {row['close_price']} USD\n"
        f"Price change compared to last hour: {row['price_change_pct'] * 100:+.4f}% ({row['price_movement']})\n"
        f"Volume: {row['volume_base']:.4f} SOL\n"
        f"Market cap: {row['market_cap']:,.2f} USD\n"
        f"Trend signal: {row['ma_crossover_description']}\n"
        f"Momentum signal: {row['macd_crossover_description']}\n"
        f"Price regime (Bollinger Bands): {row['bb_position']}\n"
        f"On-chain activity:\n"
        f"- {row['transaction_count']} transactions → {row['txn_ratio_description']} (txn ratio = {row['txn_ratio']}, compared to 24h average)\n"
        f"- {row['total_fee_sol']} SOL total fees paid\n"
        f"- Average fee per transaction: {row['avg_fee_sol']:.8f} SOL"
    ),
    axis=1
)

# %%
sol.to_csv("SOL/sol_with_text.csv", index=False)

# %% [markdown]
# ## DOGE

# %%
doge = pd.read_csv("tokens/DOGE/doge_full.csv", parse_dates=["timestamp"])
doge = doge.iloc[24:].reset_index(drop=True)
doge.head()
# Out:
#             timestamp  close_price   volume_base  volume_quote  \
# 0 2024-05-02 00:00:00     0.127801  3.165260e+08   40991031.96
# 1 2024-05-02 01:00:00     0.125845  3.059651e+08   38783962.93
# 2 2024-05-02 02:00:00     0.126181  1.998951e+08   25211351.38
# 3 2024-05-02 03:00:00     0.126435  1.077178e+08   13656346.98
# 4 2024-05-02 04:00:00     0.125160  1.981542e+08   25017373.02
#
#    transaction_count  total_value_transferred_doge  avg_fee_doge  \
# 0               5188                  5.322831e+08      0.183250
# 1              13093                  2.334874e+08      0.090736
# 2               8743                  2.674164e+08      0.152309
# 3               5830                  3.054619e+08      0.172382
# 4              31981                  4.024198e+08      0.049790
#
#    total_size_used_bytes    market_cap      ma_6  ...  \
# 0                1589128  1.881029e+10  0.128604  ...
# 1                3489638  1.842550e+10  0.128369  ...
# 2                2711506  1.819604e+10  0.128124  ...
# 3                1881013  1.816895e+10  0.127712  ...
# 4                8552289  1.822362e+10  0.126990  ...
#
#                           macd_crossover_description  txn_ratio  \
# 0  MACD (12h vs 26h EMA) is above signal line → b...     0.3307
# 1  MACD (12h vs 26h EMA) is above signal line → b...     0.8201
# 2  MACD (12h vs 26h EMA) is above signal line → b...     0.5429
# 3  MACD (12h vs 26h EMA) is above signal line → b...     0.3601
# 4  MACD (12h vs 26h EMA) is above signal line → b...     1.8342
#
#   txn_ratio_description    bb_mid    bb_std  bb_upper  bb_lower  \
# 0          low activity  0.126672  0.002865  0.132401  0.120942
# 1       normal activity  0.126380  0.002614  0.131607  0.121152
# 2          low activity  0.126241  0.002543  0.131327  0.121156
# 3          low activity  0.126329  0.002516  0.131362  0.121296
# 4        activity surge  0.126370  0.002488  0.131347  0.121394
#
#                   bb_position  price_change_pct        price_movement
# 0  within band (normal range)         -0.020795  significant decrease
# 1  within band (normal range)         -0.015309  significant decrease
# 2  within band (normal range)          0.002673       slight increase
# 3  within band (normal range)          0.002012       slight increase
# 4  within band (normal range)         -0.010083  significant decrease
#
# [5 rows x 29 columns]

# %%
doge.columns
# Out:
# Index(['timestamp', 'close_price', 'volume_base', 'volume_quote',
#        'transaction_count', 'total_value_transferred_doge', 'avg_fee_doge',
#        'total_size_used_bytes', 'market_cap', 'ma_6', 'ma_24',
#        'ma_crossover_signal', 'ma_crossover_description', 'ema_12', 'ema_26',
#        'macd', 'macd_signal', 'macd_hist', 'macd_crossover_signal',
#        'macd_crossover_description', 'txn_ratio', 'txn_ratio_description',
#        'bb_mid', 'bb_std', 'bb_upper', 'bb_lower', 'bb_position',
#        'price_change_pct', 'price_movement'],
#       dtype='object')

# %%
doge["text"] = doge.apply(
    lambda row: (
        f"Price: {row['close_price']:.8f} USD\n"
        f"Price change compared to last hour: {row['price_change_pct'] * 100:+.4f}% ({row['price_movement']})\n"
        f"Volume: {row['volume_base']:,.4f} DOGE\n"
        f"Market cap: {row['market_cap']:,.2f} USD\n"
        f"Trend signal: {row['ma_crossover_description']}\n"
        f"Momentum signal: {row['macd_crossover_description']}\n"
        f"Price regime (Bollinger Bands): {row['bb_position']}\n"
        f"On-chain activity:\n"
        f"- {row['transaction_count']} transactions → {row['txn_ratio_description']} (txn ratio = {row['txn_ratio']}, compared to 24h average)\n"
        f"- {row['total_value_transferred_doge']:.2f} DOGE transferred\n"
        f"- Average transaction fee: {row['avg_fee_doge']} DOGE\n"
        f"- {row['total_size_used_bytes'] / 1024:.4f} KB block size used"
    ),
    axis=1
)

# %%
doge.to_csv("DOGE/doge_with_text.csv", index=False)

# %% [markdown]
# ## USDT

# %%
usdt = pd.read_csv("tokens/USDT/usdt_full.csv", parse_dates=["timestamp"]) 
usdt = usdt.iloc[24:].reset_index(drop=True)
usdt.head()
# Out:
#             timestamp  close_price   volume_base  volume_quote    market_cap  \
# 0 2024-05-02 00:00:00     0.999544  9.569110e+06    9560786.23  1.106566e+11
# 1 2024-05-02 01:00:00     0.999702  6.666103e+06    6661710.90  1.104466e+11
# 2 2024-05-02 02:00:00     0.999760  8.511208e+06    8506023.03  1.106076e+11
# 3 2024-05-02 03:00:00     0.999628  1.257109e+07   12560514.98  1.105773e+11
# 4 2024-05-02 04:00:00     0.999663  4.436367e+06    4433286.13  1.104433e+11
#
#        ma_6     ma_24  ma_crossover_signal  \
# 0  0.999356  0.999282                  1.0
# 1  0.999416  0.999306                  1.0
# 2  0.999479  0.999332                  1.0
# 3  0.999541  0.999354                  1.0
# 4  0.999602  0.999377                  1.0
#
#                             ma_crossover_description    ema_12  ...      macd  \
# 0  short MA (6h) is above long MA (24h) → buy signal  0.999354  ...  0.000049
# 1  short MA (6h) is above long MA (24h) → buy signal  0.999408  ...  0.000074
# 2  short MA (6h) is above long MA (24h) → buy signal  0.999462  ...  0.000096
# 3  short MA (6h) is above long MA (24h) → buy signal  0.999487  ...  0.000102
# 4  short MA (6h) is above long MA (24h) → buy signal  0.999514  ...  0.000109
#
#    macd_signal  macd_hist  macd_crossover_signal  \
# 0     0.000042   0.000008                      1
# 1     0.000048   0.000026                      1
# 2     0.000058   0.000039                      1
# 3     0.000067   0.000036                      1
# 4     0.000075   0.000034                      1
#
#                           macd_crossover_description    bb_mid    bb_std  \
# 0  MACD (12h vs 26h EMA) is above signal line → b...  0.999314  0.000159
# 1  MACD (12h vs 26h EMA) is above signal line → b...  0.999344  0.000173
# 2  MACD (12h vs 26h EMA) is above signal line → b...  0.999371  0.000194
# 3  MACD (12h vs 26h EMA) is above signal line → b...  0.999387  0.000201
# 4  MACD (12h vs 26h EMA) is above signal line → b...  0.999427  0.000169
#
#    bb_upper  bb_lower                           bb_position
# 0  0.999632  0.998997            within band (normal range)
# 1  0.999690  0.998998  above upper band (possible breakout)
# 2  0.999758  0.998984  above upper band (possible breakout)
# 3  0.999790  0.998985            within band (normal range)
# 4  0.999765  0.999090            within band (normal range)
#
# [5 rows x 21 columns]

# %%
usdt.columns
# Out:
# Index(['timestamp', 'close_price', 'volume_base', 'volume_quote', 'market_cap',
#        'ma_6', 'ma_24', 'ma_crossover_signal', 'ma_crossover_description',
#        'ema_12', 'ema_26', 'macd', 'macd_signal', 'macd_hist',
#        'macd_crossover_signal', 'macd_crossover_description', 'bb_mid',
#        'bb_std', 'bb_upper', 'bb_lower', 'bb_position'],
#       dtype='object')

# %%
usdt["text"] = usdt.apply(
    lambda row: (
        f"Price: {row['close_price']:.8f} USD (stablecoin)\n"
        f"Volume: {row['volume_base']:.4f} USDT\n"
        f"Market cap: {row['market_cap']:,.2f} USD\n"
        f"Trend signal: {row['ma_crossover_description']}\n"
        f"Momentum signal: {row['macd_crossover_description']}\n"
        f"Price regime (Bollinger Bands): {row['bb_position']}"
    ),
    axis=1
)

# %%
usdt.to_csv("USDT/usdt_with_text.csv", index=False)

# %% [markdown]
# ## Isolating All Price Data Across 5 Tokens For Each Hour (For Later Use)

# %%
btc_price = btc[["timestamp", "close_price"]].copy()
btc_price.rename(columns={"close_price": "btc_price"}, inplace=True)
btc_price
# Out:
#                timestamp   btc_price
# 0    2024-05-02 00:00:00  57759.9547
# 1    2024-05-02 01:00:00  57109.6836
# 2    2024-05-02 02:00:00  57462.1227
# 3    2024-05-02 03:00:00  57441.6225
# 4    2024-05-02 04:00:00  57386.5479
# ...                  ...         ...
# 8011 2025-03-31 19:00:00  82447.4689
# 8012 2025-03-31 20:00:00  82439.1058
# 8013 2025-03-31 21:00:00  82567.0649
# 8014 2025-03-31 22:00:00  82412.5917
# 8015 2025-03-31 23:00:00  82560.4835
#
# [8016 rows x 2 columns]

# %%
eth_price = eth[["timestamp", "close_price"]].copy()
eth_price.rename(columns={"close_price": "eth_price"}, inplace=True)
eth_price
# Out:
#                timestamp  eth_price
# 0    2024-05-02 00:00:00  2947.5852
# 1    2024-05-02 01:00:00  2905.4601
# 2    2024-05-02 02:00:00  2917.0471
# 3    2024-05-02 03:00:00  2928.5850
# 4    2024-05-02 04:00:00  2921.4791
# ...                  ...        ...
# 8011 2025-03-31 19:00:00  1827.5233
# 8012 2025-03-31 20:00:00  1819.8772
# 8013 2025-03-31 21:00:00  1824.6029
# 8014 2025-03-31 22:00:00  1824.7112
# 8015 2025-03-31 23:00:00  1822.5282
#
# [8016 rows x 2 columns]

# %%
sol_price = sol[["timestamp", "close_price"]].copy()
sol_price.rename(columns={"close_price": "sol_price"}, inplace=True)
sol_price
# Out:
#                timestamp  sol_price
# 0    2024-05-02 00:00:00   131.4696
# 1    2024-05-02 01:00:00   129.6897
# 2    2024-05-02 02:00:00   129.6112
# 3    2024-05-02 03:00:00   130.0905
# 4    2024-05-02 04:00:00   129.5669
# ...                  ...        ...
# 8011 2025-03-31 19:00:00   125.2499
# 8012 2025-03-31 20:00:00   125.4111
# 8013 2025-03-31 21:00:00   125.7530
# 8014 2025-03-31 22:00:00   125.5478
# 8015 2025-03-31 23:00:00   124.5877
#
# [8016 rows x 2 columns]

# %%
doge_price = doge[["timestamp", "close_price"]].copy()
doge_price.rename(columns={"close_price": "doge_price"}, inplace=True)
doge_price
# Out:
#                timestamp  doge_price
# 0    2024-05-02 00:00:00    0.127801
# 1    2024-05-02 01:00:00    0.125845
# 2    2024-05-02 02:00:00    0.126181
# 3    2024-05-02 03:00:00    0.126435
# 4    2024-05-02 04:00:00    0.125160
# ...                  ...         ...
# 8011 2025-03-31 19:00:00    0.165746
# 8012 2025-03-31 20:00:00    0.165668
# 8013 2025-03-31 21:00:00    0.165791
# 8014 2025-03-31 22:00:00    0.165656
# 8015 2025-03-31 23:00:00    0.166779
#
# [8016 rows x 2 columns]

# %%
usdt_price = usdt[["timestamp", "close_price"]].copy()
usdt_price.rename(columns={'close_price': 'usdt_price'}, inplace=True)  
usdt_price
# Out:
#                timestamp  usdt_price
# 0    2024-05-02 00:00:00    0.999544
# 1    2024-05-02 01:00:00    0.999702
# 2    2024-05-02 02:00:00    0.999760
# 3    2024-05-02 03:00:00    0.999628
# 4    2024-05-02 04:00:00    0.999663
# ...                  ...         ...
# 8011 2025-03-31 19:00:00    1.000039
# 8012 2025-03-31 20:00:00    1.000005
# 8013 2025-03-31 21:00:00    0.999940
# 8014 2025-03-31 22:00:00    0.999929
# 8015 2025-03-31 23:00:00    0.999946
#
# [8016 rows x 2 columns]

# %%
all_prices = btc_price.merge(eth_price, on="timestamp") \
    .merge(sol_price, on="timestamp") \
    .merge(doge_price, on="timestamp") \
    .merge(usdt_price, on="timestamp")

all_prices
# Out:
#                timestamp   btc_price  eth_price  sol_price  doge_price  \
# 0    2024-05-02 00:00:00  57759.9547  2947.5852   131.4696    0.127801
# 1    2024-05-02 01:00:00  57109.6836  2905.4601   129.6897    0.125845
# 2    2024-05-02 02:00:00  57462.1227  2917.0471   129.6112    0.126181
# 3    2024-05-02 03:00:00  57441.6225  2928.5850   130.0905    0.126435
# 4    2024-05-02 04:00:00  57386.5479  2921.4791   129.5669    0.125160
# ...                  ...         ...        ...        ...         ...
# 8011 2025-03-31 19:00:00  82447.4689  1827.5233   125.2499    0.165746
# 8012 2025-03-31 20:00:00  82439.1058  1819.8772   125.4111    0.165668
# 8013 2025-03-31 21:00:00  82567.0649  1824.6029   125.7530    0.165791
# 8014 2025-03-31 22:00:00  82412.5917  1824.7112   125.5478    0.165656
# 8015 2025-03-31 23:00:00  82560.4835  1822.5282   124.5877    0.166779
#
#       usdt_price
# 0       0.999544
# 1       0.999702
# 2       0.999760
# 3       0.999628
# 4       0.999663
# ...          ...
# 8011    1.000039
# 8012    1.000005
# 8013    0.999940
# 8014    0.999929
# 8015    0.999946
#
# [8016 rows x 6 columns]

# %%
all_prices.to_csv("data/all_prices_across_assets.csv", index=False)

# %%
# Partition all price data into 3 regimes
all_prices_bullish = all_prices[(all_prices['timestamp'] >= '2024-11-05 00:00:00') & (all_prices['timestamp'] <= '2024-12-04 23:00:00')].copy().reset_index(drop=True)
all_prices_bullish
# Out:
#               timestamp   btc_price  eth_price  sol_price  doge_price  \
# 0   2024-11-05 00:00:00  68006.8008  2400.2317   158.5760    0.164755
# 1   2024-11-05 01:00:00  67969.5688  2409.7639   158.2116    0.162622
# 2   2024-11-05 02:00:00  67857.8633  2403.9608   158.2175    0.161914
# 3   2024-11-05 03:00:00  68216.7021  2419.2786   159.6270    0.162487
# 4   2024-11-05 04:00:00  68308.7174  2427.8065   159.9727    0.162226
# ..                  ...         ...        ...        ...         ...
# 715 2024-12-04 19:00:00  97293.2167  3846.4843   232.9248    0.416510
# 716 2024-12-04 20:00:00  98911.2251  3885.6738   232.9981    0.419737
# 717 2024-12-04 21:00:00  97839.8131  3844.4650   229.9886    0.422598
# 718 2024-12-04 22:00:00  98312.7488  3847.6644   229.4383    0.419115
# 719 2024-12-04 23:00:00  98734.3201  3843.5577   229.4531    0.433116
#
#      usdt_price
# 0      0.999386
# 1      0.999366
# 2      0.999453
# 3      0.999443
# 4      0.999453
# ..          ...
# 715    1.001477
# 716    1.002231
# 717    1.001689
# 718    1.001459
# 719    1.001465
#
# [720 rows x 6 columns]

# %%
all_prices_bearish = all_prices[(all_prices['timestamp'] >= '2025-01-22 00:00:00') & (all_prices['timestamp'] <= '2025-03-09 23:00:00')].copy().reset_index(drop=True)
all_prices_bearish
# Out:
#                timestamp    btc_price  eth_price  sol_price  doge_price  \
# 0    2025-01-22 00:00:00  105991.6920  3363.1587   253.0133    0.373459
# 1    2025-01-22 01:00:00  105822.8884  3330.5308   252.4561    0.370568
# 2    2025-01-22 02:00:00  105623.7806  3344.7382   252.6056    0.372697
# 3    2025-01-22 03:00:00  105651.3822  3332.5598   254.4701    0.373087
# 4    2025-01-22 04:00:00  105606.9847  3333.1036   255.9487    0.371775
# ...                  ...          ...        ...        ...         ...
# 1123 2025-03-09 19:00:00   82671.2826  2041.4972   129.2483    0.171616
# 1124 2025-03-09 20:00:00   83138.2554  2048.7784   128.4520    0.171554
# 1125 2025-03-09 21:00:00   81939.4262  2026.2881   128.1068    0.169298
# 1126 2025-03-09 22:00:00   80393.8015  2011.2138   127.0260    0.167321
# 1127 2025-03-09 23:00:00   80795.4492  2021.2045   126.6880    0.168523
#
#       usdt_price
# 0       0.999969
# 1       0.999978
# 2       0.999993
# 3       1.000090
# 4       0.999906
# ...          ...
# 1123    1.000643
# 1124    1.000754
# 1125    1.000761
# 1126    1.000490
# 1127    1.000484
#
# [1128 rows x 6 columns]

# %%
all_prices_sideways = all_prices[(all_prices['timestamp'] >= '2024-08-09 00:00:00') & (all_prices['timestamp'] <= '2024-09-07 23:00:00')].copy().reset_index(drop=True)
all_prices_sideways
# Out:
#               timestamp   btc_price  eth_price  sol_price  doge_price  \
# 0   2024-08-09 00:00:00  61257.4370  2667.4673   161.4598    0.107046
# 1   2024-08-09 01:00:00  61443.0406  2672.4434   160.5484    0.106111
# 2   2024-08-09 02:00:00  61289.2862  2671.5673   158.6511    0.105677
# 3   2024-08-09 03:00:00  61404.4036  2696.6841   159.2750    0.106241
# 4   2024-08-09 04:00:00  60764.4714  2661.8933   156.3544    0.104452
# ..                  ...         ...        ...        ...         ...
# 715 2024-09-07 19:00:00  54458.7186  2292.5390   128.5441    0.095121
# 716 2024-09-07 20:00:00  54230.0669  2273.6253   127.5057    0.095193
# 717 2024-09-07 21:00:00  53971.0896  2266.3987   126.9849    0.095151
# 718 2024-09-07 22:00:00  54003.1837  2266.6692   126.9164    0.094951
# 719 2024-09-07 23:00:00  54199.5777  2275.2086   127.8175    0.095456
#
#      usdt_price
# 0      1.000368
# 1      1.000330
# 2      1.000233
# 3      1.000234
# 4      1.000219
# ..          ...
# 715    1.000779
# 716    1.000890
# 717    1.000932
# 718    1.000933
# 719    1.000761
#
# [720 rows x 6 columns]

# %%
# Save
all_prices_bullish.to_csv("data/regimes/bullish/all_prices_bullish.csv", index=False)
all_prices_bearish.to_csv("data/regimes/bearish/all_prices_bearish.csv", index=False)
all_prices_sideways.to_csv("data/regimes/sideways/all_prices_sideways.csv", index=False)

# %% [markdown]
# # Part 2: Macro Factors

# %%
import pandas_datareader.data as web
import datetime

# %% [markdown]
# ### 1. DGS10: 10-Year Treasury Constant Maturity Rate
# - Represents the interest rate at which the U.S. government can borrow money for 10 years
# - When the 10-year yield rises, it's often interpreted as:
#     - Expectation of higher inflation
#     - Stronger economic growth
#     - Or a signal that the Fed might short-term rates
# - A macro indicator of long-term sentiment in financial markets

# %%
start = datetime.datetime(2024, 5, 2)
end = datetime.datetime(2025, 4, 1)

tnx = web.DataReader("DGS10", 'fred', start, end)
tnx.index = pd.to_datetime(tnx.index)
hourly_index = pd.date_range(start=start, end=end, freq='H')
tnx_hourly = tnx.reindex(hourly_index, method='ffill')
tnx_hourly.reset_index(inplace=True)
tnx_hourly.rename(columns={'index': 'timestamp'}, inplace=True)
tnx_hourly = tnx_hourly[:-1].copy()

tnx_hourly['DGS10'] = tnx_hourly['DGS10'].interpolate(method='linear').round(2)
tnx_hourly
# Out:
#                timestamp  DGS10
# 0    2024-05-02 00:00:00   4.58
# 1    2024-05-02 01:00:00   4.58
# 2    2024-05-02 02:00:00   4.58
# 3    2024-05-02 03:00:00   4.58
# 4    2024-05-02 04:00:00   4.58
# ...                  ...    ...
# 8011 2025-03-31 19:00:00   4.23
# 8012 2025-03-31 20:00:00   4.23
# 8013 2025-03-31 21:00:00   4.23
# 8014 2025-03-31 22:00:00   4.23
# 8015 2025-03-31 23:00:00   4.23
#
# [8016 rows x 2 columns]

# %% [markdown]
# ### 2. Oil
#
# - The daily spot price of West Texas Intermediate (WTI) crude oil, priced in U.S. dollars per barrel.
# - WTI is one of the world's most important benchmark crude oils (alongside Brent).
# - What does it mean when DCOILWTICO rises?
#     - Stronger global demand, supply shocks, or geopolitical risks.
#     - Signals rising inflation pressure.
#     - May lead to interest rate hikes.
#     - Investors might shift toward energy stocks and reduce exposure to tech or consumer sectors.

# %%
oil = web.DataReader("DCOILWTICO", 'fred', start, end)
oil.index = pd.to_datetime(oil.index)
oil_hourly = oil.reindex(hourly_index, method='ffill').reset_index().rename(columns={'index': 'timestamp', 'DCOILWTICO': 'crude_oil'})
oil_hourly = oil_hourly[:-1].copy()

oil_hourly["crude_oil"] = oil_hourly["crude_oil"].interpolate(method='linear').round(2)
oil_hourly
# Out:
#                timestamp  crude_oil
# 0    2024-05-02 00:00:00      80.59
# 1    2024-05-02 01:00:00      80.59
# 2    2024-05-02 02:00:00      80.59
# 3    2024-05-02 03:00:00      80.59
# 4    2024-05-02 04:00:00      80.59
# ...                  ...        ...
# 8011 2025-03-31 19:00:00      71.87
# 8012 2025-03-31 20:00:00      71.87
# 8013 2025-03-31 21:00:00      71.87
# 8014 2025-03-31 22:00:00      71.87
# 8015 2025-03-31 23:00:00      71.87
#
# [8016 rows x 2 columns]

# %% [markdown]
# ### 3. DXY: U.S. Dollar Index
# - It measures the value of the U.S. dollar relative to a basket of major foreign currencies
# - A rising DXY means the U.S. dollar is getting stronger vs other major currencies.
# - A stronger dollar makes U.S. exports more expensive and imports cheaper.
# - A strong dollar can reduce inflation by lowering import prices.
# - Often seen as a safe-haven asset—rising during global uncertainty.

# %%
# Downloaded online
dxy = pd.read_csv("data/dxy.csv")
dxy
# Out:
#            Date    Open    High     Low   Close
# 0    03/31/2025  104.01  104.39  103.75  104.21
# 1    03/28/2025  104.28  104.50  103.90  104.04
# 2    03/27/2025  104.65  104.65  104.07  104.34
# 3    03/26/2025  104.25  104.68  104.18  104.55
# 4    03/25/2025  104.33  104.47  103.94  104.18
# ..          ...     ...     ...     ...     ...
# 233  05/08/2024  105.42  105.64  105.39  105.55
# 234  05/07/2024  105.14  105.45  105.03  105.41
# 235  05/06/2024  105.05  105.20  104.87  105.05
# 236  05/03/2024  105.31  105.37  104.52  105.03
# 237  05/02/2024  105.73  105.90  105.30  105.30
#
# [238 rows x 5 columns]

# %%
dxy['Date'] = pd.to_datetime(dxy['Date'])
dxy = dxy.sort_values('Date')
dxy = dxy[['Date', 'Close']].rename(columns={'Date': 'date', 'Close': 'dxy'})
dxy = dxy.set_index('date').asfreq('D')
dxy['dxy'] = dxy['dxy'].interpolate(method='linear')

hourly_index = pd.date_range(start=dxy.index.min(), end=dxy.index.max() + pd.Timedelta(days=1), freq='H')
hourly_index = hourly_index[:-1]
dxy_hourly = dxy.reindex(hourly_index, method='ffill').reset_index()
dxy_hourly = dxy_hourly.rename(columns={'index': 'timestamp'})

# 保留两位小数
dxy_hourly['dxy'] = dxy_hourly['dxy'].round(2)
dxy_hourly
# Out:
#                timestamp     dxy
# 0    2024-05-02 00:00:00  105.30
# 1    2024-05-02 01:00:00  105.30
# 2    2024-05-02 02:00:00  105.30
# 3    2024-05-02 03:00:00  105.30
# 4    2024-05-02 04:00:00  105.30
# ...                  ...     ...
# 8011 2025-03-31 19:00:00  104.21
# 8012 2025-03-31 20:00:00  104.21
# 8013 2025-03-31 21:00:00  104.21
# 8014 2025-03-31 22:00:00  104.21
# 8015 2025-03-31 23:00:00  104.21
#
# [8016 rows x 2 columns]

# %% [markdown]
# ### 4. VIX
# - CBOE Volatility Index, "the fear index"
# - It measures the market's expectation of 30-day volatility in the S&P 500 index, based on options pricing
# - What does it mean when VIX rises?
#     - Investors expect more market turbulence in the next month.
#     - Often occurs during times of financial stress, geopolitical tension, or economic uncertainty.
#     - Can signal a sell-off or correction in equities, especially the S&P 500.
#     - Traders may move to safe assets like bonds, gold, or the dollar.

# %%
vix = web.DataReader("VIXCLS", 'fred', start, end)
vix.index = pd.to_datetime(vix.index)
vix = vix.asfreq('D')
vix['VIXCLS'] = vix['VIXCLS'].interpolate(method='linear')

vix_hourly = vix.reindex(hourly_index, method='ffill').reset_index().rename(columns={'index': 'timestamp', 'VIXCLS': 'vix'})
vix_hourly['vix'] = vix_hourly['vix'].round(2) 
vix_hourly
# Out:
#                timestamp    vix
# 0    2024-05-02 00:00:00  14.68
# 1    2024-05-02 01:00:00  14.68
# 2    2024-05-02 02:00:00  14.68
# 3    2024-05-02 03:00:00  14.68
# 4    2024-05-02 04:00:00  14.68
# ...                  ...    ...
# 8011 2025-03-31 19:00:00  22.28
# 8012 2025-03-31 20:00:00  22.28
# 8013 2025-03-31 21:00:00  22.28
# 8014 2025-03-31 22:00:00  22.28
# 8015 2025-03-31 23:00:00  22.28
#
# [8016 rows x 2 columns]

# %% [markdown]
# ### 5. Gold Price
# - USD per troy ounce
# - Gold is considered a safe-haven asset, especially in times of crisis or inflation
# - Rising gold prices may indicate risk aversion, while falling prices suggest confidence in equities or fiat currencies
# - Often moves inversely to U.S. real interest rates and the dollar index (DXY)

# %%
# Downloaded from kaggle
gold = pd.read_csv("data/gold_hourly.csv", sep=';')
gold = gold[['Date', 'Close']]
gold.rename(columns={'Date': 'timestamp', 'Close': 'gold_price'}, inplace=True)
gold['timestamp'] = pd.to_datetime(gold['timestamp'])
gold = gold[gold['timestamp'] >= '2024-05-02'].copy()
gold.reset_index(drop=True, inplace=True)
gold = gold[:-1].copy()
gold
# Out:
#                timestamp  gold_price
# 0    2024-05-02 01:00:00     2320.83
# 1    2024-05-02 02:00:00     2323.78
# 2    2024-05-02 03:00:00     2324.43
# 3    2024-05-02 04:00:00     2324.13
# 4    2024-05-02 05:00:00     2320.20
# ...                  ...         ...
# 4266 2025-01-31 19:00:00     2808.76
# 4267 2025-01-31 20:00:00     2798.91
# 4268 2025-01-31 21:00:00     2796.30
# 4269 2025-01-31 22:00:00     2800.88
# 4270 2025-01-31 23:00:00     2799.23
#
# [4271 rows x 2 columns]

# %%
gold.set_index('timestamp', inplace=True)
start_time = pd.Timestamp('2024-05-02 00:00:00')
end_time = pd.Timestamp('2025-01-31 23:00:00')
full_range = pd.date_range(start=start_time, end=end_time, freq='H')
gold_part1 = gold.reindex(full_range)
gold_part1.reset_index(inplace=True)
gold_part1.rename(columns={'index': 'timestamp'}, inplace=True)
gold_part1['gold_price'] = gold_part1['gold_price'].bfill()
# 这是从网上下载的数据，但是只到25年1月底，后面的数据自己手动按照yahoo finance上补全的
# https://finance.yahoo.com/quote/GC%3DF/history/?period1=1714521600&period2=1743379200

# %%
gold_part1.to_csv("data/gold_hourly_part1.csv", index=False)

# %%
gold_temp = pd.read_csv("data/gold_hourly_temp.csv", parse_dates=["timestamp"])
gold_temp["timestamp"] = pd.to_datetime(gold_temp["timestamp"], dayfirst=True)
gold_temp["gold_price"] = gold_temp["gold_price"].interpolate(method="linear").round(2)
gold_temp
# Out:
#                timestamp  gold_price
# 0    2024-05-02 00:00:00     2320.83
# 1    2024-05-02 01:00:00     2320.83
# 2    2024-05-02 02:00:00     2323.78
# 3    2024-05-02 03:00:00     2324.43
# 4    2024-05-02 04:00:00     2324.13
# ...                  ...         ...
# 8011 2025-03-31 19:00:00     3086.50
# 8012 2025-03-31 20:00:00     3086.50
# 8013 2025-03-31 21:00:00     3086.50
# 8014 2025-03-31 22:00:00     3086.50
# 8015 2025-03-31 23:00:00     3086.50
#
# [8016 rows x 2 columns]

# %%
gold_hourly = gold_temp.copy()

# %% [markdown]
# ### 6. SP500
#
# - S&P 500 Index
# - It tracks the performance of 500 large-cap U.S. companies, including names like Apple, Microsoft, Amazon, etc.
# - Unit: Index points (not USD)
# - What does it mean when the S&P 500 rises?
#     - Investors are more optimistic about U.S. corporate earnings and the economic outlook.
#     - Usually reflects lower perceived risk, accommodative monetary policy, or strong growth.
#     - May lead to increased investments in equities and risk assets.

# %%
start = datetime.datetime(2024, 5, 2)
end = datetime.datetime(2025, 3, 31)
sp500 = web.DataReader("SP500", "fred", start, end)
sp500.index = pd.to_datetime(sp500.index)
sp500 = sp500.asfreq('D')
sp500["SP500"] = sp500["SP500"].interpolate(method='linear')    
sp500_hourly = sp500.reindex(hourly_index, method='ffill').reset_index().rename(columns={'index': 'timestamp', 'SP500': 'sp500'})
sp500_hourly['sp500'] = sp500_hourly['sp500'].round(2)
sp500_hourly
# Out:
#                timestamp    sp500
# 0    2024-05-02 00:00:00  5064.20
# 1    2024-05-02 01:00:00  5064.20
# 2    2024-05-02 02:00:00  5064.20
# 3    2024-05-02 03:00:00  5064.20
# 4    2024-05-02 04:00:00  5064.20
# ...                  ...      ...
# 8011 2025-03-31 19:00:00  5611.85
# 8012 2025-03-31 20:00:00  5611.85
# 8013 2025-03-31 21:00:00  5611.85
# 8014 2025-03-31 22:00:00  5611.85
# 8015 2025-03-31 23:00:00  5611.85
#
# [8016 rows x 2 columns]

# %% [markdown]
# ### Merge Macro Data Together!

# %%
macro1 = tnx_hourly.merge(oil_hourly, on='timestamp')
macro1
# Out:
#                timestamp  DGS10  crude_oil
# 0    2024-05-02 00:00:00   4.58      80.59
# 1    2024-05-02 01:00:00   4.58      80.59
# 2    2024-05-02 02:00:00   4.58      80.59
# 3    2024-05-02 03:00:00   4.58      80.59
# 4    2024-05-02 04:00:00   4.58      80.59
# ...                  ...    ...        ...
# 8011 2025-03-31 19:00:00   4.23      71.87
# 8012 2025-03-31 20:00:00   4.23      71.87
# 8013 2025-03-31 21:00:00   4.23      71.87
# 8014 2025-03-31 22:00:00   4.23      71.87
# 8015 2025-03-31 23:00:00   4.23      71.87
#
# [8016 rows x 3 columns]

# %%
macro2 = macro1.merge(dxy_hourly, on='timestamp')
macro2
# Out:
#                timestamp  DGS10  crude_oil     dxy
# 0    2024-05-02 00:00:00   4.58      80.59  105.30
# 1    2024-05-02 01:00:00   4.58      80.59  105.30
# 2    2024-05-02 02:00:00   4.58      80.59  105.30
# 3    2024-05-02 03:00:00   4.58      80.59  105.30
# 4    2024-05-02 04:00:00   4.58      80.59  105.30
# ...                  ...    ...        ...     ...
# 8011 2025-03-31 19:00:00   4.23      71.87  104.21
# 8012 2025-03-31 20:00:00   4.23      71.87  104.21
# 8013 2025-03-31 21:00:00   4.23      71.87  104.21
# 8014 2025-03-31 22:00:00   4.23      71.87  104.21
# 8015 2025-03-31 23:00:00   4.23      71.87  104.21
#
# [8016 rows x 4 columns]

# %%
macro3 = macro2.merge(vix_hourly, on='timestamp')
macro3
# Out:
#                timestamp  DGS10  crude_oil     dxy    vix
# 0    2024-05-02 00:00:00   4.58      80.59  105.30  14.68
# 1    2024-05-02 01:00:00   4.58      80.59  105.30  14.68
# 2    2024-05-02 02:00:00   4.58      80.59  105.30  14.68
# 3    2024-05-02 03:00:00   4.58      80.59  105.30  14.68
# 4    2024-05-02 04:00:00   4.58      80.59  105.30  14.68
# ...                  ...    ...        ...     ...    ...
# 8011 2025-03-31 19:00:00   4.23      71.87  104.21  22.28
# 8012 2025-03-31 20:00:00   4.23      71.87  104.21  22.28
# 8013 2025-03-31 21:00:00   4.23      71.87  104.21  22.28
# 8014 2025-03-31 22:00:00   4.23      71.87  104.21  22.28
# 8015 2025-03-31 23:00:00   4.23      71.87  104.21  22.28
#
# [8016 rows x 5 columns]

# %%
macro4 = macro3.merge(gold_hourly, on='timestamp')
macro4
# Out:
#                timestamp  DGS10  crude_oil     dxy    vix  gold_price
# 0    2024-05-02 00:00:00   4.58      80.59  105.30  14.68     2320.83
# 1    2024-05-02 01:00:00   4.58      80.59  105.30  14.68     2320.83
# 2    2024-05-02 02:00:00   4.58      80.59  105.30  14.68     2323.78
# 3    2024-05-02 03:00:00   4.58      80.59  105.30  14.68     2324.43
# 4    2024-05-02 04:00:00   4.58      80.59  105.30  14.68     2324.13
# ...                  ...    ...        ...     ...    ...         ...
# 8011 2025-03-31 19:00:00   4.23      71.87  104.21  22.28     3086.50
# 8012 2025-03-31 20:00:00   4.23      71.87  104.21  22.28     3086.50
# 8013 2025-03-31 21:00:00   4.23      71.87  104.21  22.28     3086.50
# 8014 2025-03-31 22:00:00   4.23      71.87  104.21  22.28     3086.50
# 8015 2025-03-31 23:00:00   4.23      71.87  104.21  22.28     3086.50
#
# [8016 rows x 6 columns]

# %%
macro5 = macro4.merge(sp500_hourly, on='timestamp')
macro5
# Out:
#                timestamp  DGS10  crude_oil     dxy    vix  gold_price    sp500
# 0    2024-05-02 00:00:00   4.58      80.59  105.30  14.68     2320.83  5064.20
# 1    2024-05-02 01:00:00   4.58      80.59  105.30  14.68     2320.83  5064.20
# 2    2024-05-02 02:00:00   4.58      80.59  105.30  14.68     2323.78  5064.20
# 3    2024-05-02 03:00:00   4.58      80.59  105.30  14.68     2324.43  5064.20
# 4    2024-05-02 04:00:00   4.58      80.59  105.30  14.68     2324.13  5064.20
# ...                  ...    ...        ...     ...    ...         ...      ...
# 8011 2025-03-31 19:00:00   4.23      71.87  104.21  22.28     3086.50  5611.85
# 8012 2025-03-31 20:00:00   4.23      71.87  104.21  22.28     3086.50  5611.85
# 8013 2025-03-31 21:00:00   4.23      71.87  104.21  22.28     3086.50  5611.85
# 8014 2025-03-31 22:00:00   4.23      71.87  104.21  22.28     3086.50  5611.85
# 8015 2025-03-31 23:00:00   4.23      71.87  104.21  22.28     3086.50  5611.85
#
# [8016 rows x 7 columns]

# %%
macro = macro5.copy()
macro.isna().sum()
# Out:
# timestamp     0
# DGS10         0
# crude_oil     0
# dxy           0
# vix           0
# gold_price    0
# sp500         0
# dtype: int64

# %%
# Add a column to convert all the values into a single text column
def format_macro_text(row):
    return (
        f"- 10-Year Treasury Yield (DGS10): U.S. nominal government bond yield - {row['DGS10']}%\n"
        f"- Crude Oil Price (WTI): Spot price in USD per barrel - ${row['crude_oil']}\n"
        f"- U.S. Dollar Index (DXY): {row['dxy']}\n"
        f"- Gold Price (Spot): USD per troy ounce - ${row['gold_price']}\n"
        f"- S&P 500 Index: {row['sp500']}\n"
        f"- CBOE Volatility Index (VIX): 30-day implied volatility of S&P 500 index options - {row['vix']}"
    )

macro["text"] = macro.apply(format_macro_text, axis=1)
macro.head()
# Out:
#             timestamp  DGS10  crude_oil    dxy    vix  gold_price   sp500  \
# 0 2024-05-02 00:00:00   4.58      80.59  105.3  14.68     2320.83  5064.2
# 1 2024-05-02 01:00:00   4.58      80.59  105.3  14.68     2320.83  5064.2
# 2 2024-05-02 02:00:00   4.58      80.59  105.3  14.68     2323.78  5064.2
# 3 2024-05-02 03:00:00   4.58      80.59  105.3  14.68     2324.43  5064.2
# 4 2024-05-02 04:00:00   4.58      80.59  105.3  14.68     2324.13  5064.2
#
#                                                 text
# 0  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4  - 10-Year Treasury Yield (DGS10): U.S. nominal...

# %%
macro = macro[3:].reset_index(drop=True)
macro
# Out:
#                timestamp  DGS10  crude_oil     dxy    vix  gold_price  \
# 0    2024-05-02 03:00:00   4.58      80.59  105.30  14.68     2324.43
# 1    2024-05-02 04:00:00   4.58      80.59  105.30  14.68     2324.13
# 2    2024-05-02 05:00:00   4.58      80.59  105.30  14.68     2320.20
# 3    2024-05-02 06:00:00   4.58      80.59  105.30  14.68     2319.50
# 4    2024-05-02 07:00:00   4.58      80.59  105.30  14.68     2318.20
# ...                  ...    ...        ...     ...    ...         ...
# 8008 2025-03-31 19:00:00   4.23      71.87  104.21  22.28     3086.50
# 8009 2025-03-31 20:00:00   4.23      71.87  104.21  22.28     3086.50
# 8010 2025-03-31 21:00:00   4.23      71.87  104.21  22.28     3086.50
# 8011 2025-03-31 22:00:00   4.23      71.87  104.21  22.28     3086.50
# 8012 2025-03-31 23:00:00   4.23      71.87  104.21  22.28     3086.50
#
#         sp500                                               text
# 0     5064.20  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1     5064.20  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2     5064.20  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3     5064.20  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4     5064.20  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ...       ...                                                ...
# 8008  5611.85  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8009  5611.85  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8010  5611.85  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8011  5611.85  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8012  5611.85  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [8013 rows x 8 columns]

# %%
macro.to_csv("data/macro.csv", index=False)

# %%
macro_text = macro[['timestamp','text']].copy()
macro_text.rename(columns={'text':'macro_text'}, inplace=True)
macro_text.head()  # 8013 rows
# Out:
#             timestamp                                         macro_text
# 0 2024-05-02 03:00:00  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1 2024-05-02 04:00:00  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2 2024-05-02 05:00:00  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3 2024-05-02 06:00:00  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4 2024-05-02 07:00:00  - 10-Year Treasury Yield (DGS10): U.S. nominal...

# %% [markdown]
# # Part 3: Combine Texts to Form Prompts (Use 4h)

# %%
combined = pd.DataFrame({
    "timestamp": btc["timestamp"],
    "btc_text": btc["text"],
    "eth_text": eth["text"],
    "sol_text": sol["text"],
    "doge_text": doge["text"],
    "usdt_text": usdt["text"],
})

combined["all_texts"] = combined.apply(
    lambda row: (
        f"[BTC]\n{row['btc_text']}\n\n"
        f"[ETH]\n{row['eth_text']}\n\n"
        f"[SOL]\n{row['sol_text']}\n\n"
        f"[DOGE]\n{row['doge_text']}\n\n"
        f"[USDT]\n{row['usdt_text']}"   
    ),
    
    axis=1
)

# %% [markdown]
# ### K = 3

# %%
# Sliding window
K = 3
combined["all_texts_3h"] = None
for i in range(K - 1, len(combined)):
    window_texts = combined.loc[i - K + 1 : i, "all_texts"].tolist()
    combined.at[i, "all_texts_3h"] = "\n--------------------------------------------------\n".join(
        [f"=== Hour -{K - j} ===\n{text}" for j, text in enumerate(window_texts)]
    )

# %%
print(combined["all_texts_3h"].iloc[2])
# Out:
# === Hour -3 ===
# [BTC]
# Price: 57759.9547 USD
# Price change compared to last hour: -0.9957% (slight decrease)
# Volume: 11297.3861 BTC
# Market cap: 1,151,677,489,315.15 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 12908 transactions → low activity (txn ratio = 0.6669, compared to 24h average)
# - 31194 active wallets
# - 32819.8232 BTC transferred
# - Average transaction fee: 0.00007967
# - 6.4825 MB block size used
#
# [ETH]
# Price: 2947.5852 USD
# Price change compared to last hour: -0.7934% (slight decrease)
# Volume: 68867.9318 ETH
# Market cap: 364,276,973,974.75 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46619 transactions → normal activity (txn ratio = 0.9305, compared to 24h average)
# - 24704 active wallets
# - 19784.0181 ETH transferred
# - 6.8238 Gwei average gas price
# - 4,512,793,203 total gas used
#
# [SOL]
# Price: 131.4696 USD
# Price change compared to last hour: -2.3473% (significant decrease)
# Volume: 739088.8957 SOL
# Market cap: 60,292,554,289.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9021681 transactions → normal activity (txn ratio = 1.0692, compared to 24h average)
# - 280.9976 SOL total fees paid
# - Average fee per transaction: 0.00003115 SOL
#
# [DOGE]
# Price: 0.12780137 USD
# Price change compared to last hour: -2.0795% (significant decrease)
# Volume: 316,526,023.1488 DOGE
# Market cap: 18,810,287,917.28 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5188 transactions → low activity (txn ratio = 0.3307, compared to 24h average)
# - 532283108.06 DOGE transferred
# - Average transaction fee: 0.18325 DOGE
# - 1551.8828 KB block size used
#
# [USDT]
# Price: 0.99954376 USD (stablecoin)
# Volume: 9569110.3408 USDT
# Market cap: 110,656,637,832.43 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 57109.6836 USD
# Price change compared to last hour: -1.1258% (significant decrease)
# Volume: 14704.0150 BTC
# Market cap: 1,137,037,529,278.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10342 transactions → low activity (txn ratio = 0.5521, compared to 24h average)
# - 41382 active wallets
# - 33190.3908 BTC transferred
# - Average transaction fee: 0.00011356
# - 6.4652 MB block size used
#
# [ETH]
# Price: 2905.4601 USD
# Price change compared to last hour: -1.4291% (significant decrease)
# Volume: 111094.2636 ETH
# Market cap: 359,924,892,769.84 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47028 transactions → normal activity (txn ratio = 0.9409, compared to 24h average)
# - 24418 active wallets
# - 27487.6252 ETH transferred
# - 8.8225 Gwei average gas price
# - 4,500,709,266 total gas used
#
# [SOL]
# Price: 129.6897 USD
# Price change compared to last hour: -1.3538% (significant decrease)
# Volume: 612510.1719 SOL
# Market cap: 58,680,430,144.41 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8822319 transactions → normal activity (txn ratio = 1.048, compared to 24h average)
# - 243.0346 SOL total fees paid
# - Average fee per transaction: 0.00002755 SOL
#
# [DOGE]
# Price: 0.12584491 USD
# Price change compared to last hour: -1.5309% (significant decrease)
# Volume: 305,965,050.6318 DOGE
# Market cap: 18,425,500,262.91 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13093 transactions → normal activity (txn ratio = 0.8201, compared to 24h average)
# - 233487389.16 DOGE transferred
# - Average transaction fee: 0.090736 DOGE
# - 3407.8496 KB block size used
#
# [USDT]
# Price: 0.99970228 USD (stablecoin)
# Volume: 6666103.3191 USDT
# Market cap: 110,446,577,068.57 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 57462.1227 USD
# Price change compared to last hour: +0.6171% (slight increase)
# Volume: 8106.6418 BTC
# Market cap: 1,123,568,185,488.55 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 24016 transactions → activity surge (txn ratio = 1.2741, compared to 24h average)
# - 28971 active wallets
# - 15421.4783 BTC transferred
# - Average transaction fee: 0.00004753
# - 8.0182 MB block size used
#
# [ETH]
# Price: 2917.0471 USD
# Price change compared to last hour: +0.3988% (slight increase)
# Volume: 86947.9272 ETH
# Market cap: 355,701,554,200.52 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47036 transactions → normal activity (txn ratio = 0.942, compared to 24h average)
# - 25627 active wallets
# - 59520.5448 ETH transferred
# - 7.0086 Gwei average gas price
# - 4,550,477,735 total gas used
#
# [SOL]
# Price: 129.6112 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 539810.0675 SOL
# Market cap: 58,226,094,177.67 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9235352 transactions → normal activity (txn ratio = 1.0928, compared to 24h average)
# - 238.7772 SOL total fees paid
# - Average fee per transaction: 0.00002585 SOL
#
# [DOGE]
# Price: 0.12618126 USD
# Price change compared to last hour: +0.2673% (slight increase)
# Volume: 199,895,131.1956 DOGE
# Market cap: 18,196,044,593.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8743 transactions → low activity (txn ratio = 0.5429, compared to 24h average)
# - 267416410.72 DOGE transferred
# - Average transaction fee: 0.152309 DOGE
# - 2647.9551 KB block size used
#
# [USDT]
# Price: 0.99976003 USD (stablecoin)
# Volume: 8511208.0414 USDT
# Market cap: 110,607,559,170.01 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)

# %%
# Add Instruction to Form Prompts
combined["prompt_3h_v1"] = combined["all_texts_3h"].apply(
    lambda x: (
        "You are a multi-asset crypto market analyst supporting a portfolio management system.\n\n"
        "Your task is to analyze the following market data to assist in making multi-asset allocation decisions across five cryptocurrencies: BTC, ETH, SOL, DOGE, and USDT.\n\n"
        "Below is a chronological snapshot of hourly market data for the last 3 hours, from oldest to newest.\n"
        "The data includes pricing, technical indicators, and on-chain activity for each asset.\n"
        "Start with a brief section **Overall Market Summary**.\n"
        "Then, under the section **Asset-Specific Analysis**, write a short analysis of market behavior for each asset (1–2 sentences).\n"
        "No other sections needed.\n"
        "Be data-driven, factual, concise, and professional. Use clear headings.\n\n"
        + x
    ) if pd.notna(x) else None
)

# %%
print(combined["prompt_3h_v1"].iloc[2])
# Out:
# You are a multi-asset crypto market analyst supporting a portfolio management system.
#
# Your task is to analyze the following market data to assist in making multi-asset allocation decisions across five cryptocurrencies: BTC, ETH, SOL, DOGE, and USDT.
#
# Below is a chronological snapshot of hourly market data for the last 3 hours, from oldest to newest.
# The data includes pricing, technical indicators, and on-chain activity for each asset.
# Start with a brief section **Overall Market Summary**.
# Then, under the section **Asset-Specific Analysis**, write a short analysis of market behavior for each asset (1–2 sentences).
# No other sections needed.
# Be data-driven, factual, concise, and professional. Use clear headings.
#
# === Hour -3 ===
# [BTC]
# Price: 57759.9547 USD
# Price change compared to last hour: -0.9957% (slight decrease)
# Volume: 11297.3861 BTC
# Market cap: 1,151,677,489,315.15 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 12908 transactions → low activity (txn ratio = 0.6669, compared to 24h average)
# - 31194 active wallets
# - 32819.8232 BTC transferred
# - Average transaction fee: 0.00007967
# - 6.4825 MB block size used
#
# [ETH]
# Price: 2947.5852 USD
# Price change compared to last hour: -0.7934% (slight decrease)
# Volume: 68867.9318 ETH
# Market cap: 364,276,973,974.75 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46619 transactions → normal activity (txn ratio = 0.9305, compared to 24h average)
# - 24704 active wallets
# - 19784.0181 ETH transferred
# - 6.8238 Gwei average gas price
# - 4,512,793,203 total gas used
#
# [SOL]
# Price: 131.4696 USD
# Price change compared to last hour: -2.3473% (significant decrease)
# Volume: 739088.8957 SOL
# Market cap: 60,292,554,289.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9021681 transactions → normal activity (txn ratio = 1.0692, compared to 24h average)
# - 280.9976 SOL total fees paid
# - Average fee per transaction: 0.00003115 SOL
#
# [DOGE]
# Price: 0.12780137 USD
# Price change compared to last hour: -2.0795% (significant decrease)
# Volume: 316,526,023.1488 DOGE
# Market cap: 18,810,287,917.28 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5188 transactions → low activity (txn ratio = 0.3307, compared to 24h average)
# - 532283108.06 DOGE transferred
# - Average transaction fee: 0.18325 DOGE
# - 1551.8828 KB block size used
#
# [USDT]
# Price: 0.99954376 USD (stablecoin)
# Volume: 9569110.3408 USDT
# Market cap: 110,656,637,832.43 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 57109.6836 USD
# Price change compared to last hour: -1.1258% (significant decrease)
# Volume: 14704.0150 BTC
# Market cap: 1,137,037,529,278.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10342 transactions → low activity (txn ratio = 0.5521, compared to 24h average)
# - 41382 active wallets
# - 33190.3908 BTC transferred
# - Average transaction fee: 0.00011356
# - 6.4652 MB block size used
#
# [ETH]
# Price: 2905.4601 USD
# Price change compared to last hour: -1.4291% (significant decrease)
# Volume: 111094.2636 ETH
# Market cap: 359,924,892,769.84 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47028 transactions → normal activity (txn ratio = 0.9409, compared to 24h average)
# - 24418 active wallets
# - 27487.6252 ETH transferred
# - 8.8225 Gwei average gas price
# - 4,500,709,266 total gas used
#
# [SOL]
# Price: 129.6897 USD
# Price change compared to last hour: -1.3538% (significant decrease)
# Volume: 612510.1719 SOL
# Market cap: 58,680,430,144.41 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8822319 transactions → normal activity (txn ratio = 1.048, compared to 24h average)
# - 243.0346 SOL total fees paid
# - Average fee per transaction: 0.00002755 SOL
#
# [DOGE]
# Price: 0.12584491 USD
# Price change compared to last hour: -1.5309% (significant decrease)
# Volume: 305,965,050.6318 DOGE
# Market cap: 18,425,500,262.91 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13093 transactions → normal activity (txn ratio = 0.8201, compared to 24h average)
# - 233487389.16 DOGE transferred
# - Average transaction fee: 0.090736 DOGE
# - 3407.8496 KB block size used
#
# [USDT]
# Price: 0.99970228 USD (stablecoin)
# Volume: 6666103.3191 USDT
# Market cap: 110,446,577,068.57 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 57462.1227 USD
# Price change compared to last hour: +0.6171% (slight increase)
# Volume: 8106.6418 BTC
# Market cap: 1,123,568,185,488.55 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 24016 transactions → activity surge (txn ratio = 1.2741, compared to 24h average)
# - 28971 active wallets
# - 15421.4783 BTC transferred
# - Average transaction fee: 0.00004753
# - 8.0182 MB block size used
#
# [ETH]
# Price: 2917.0471 USD
# Price change compared to last hour: +0.3988% (slight increase)
# Volume: 86947.9272 ETH
# Market cap: 355,701,554,200.52 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47036 transactions → normal activity (txn ratio = 0.942, compared to 24h average)
# - 25627 active wallets
# - 59520.5448 ETH transferred
# - 7.0086 Gwei average gas price
# - 4,550,477,735 total gas used
#
# [SOL]
# Price: 129.6112 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 539810.0675 SOL
# Market cap: 58,226,094,177.67 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9235352 transactions → normal activity (txn ratio = 1.0928, compared to 24h average)
# - 238.7772 SOL total fees paid
# - Average fee per transaction: 0.00002585 SOL
#
# [DOGE]
# Price: 0.12618126 USD
# Price change compared to last hour: +0.2673% (slight increase)
# Volume: 199,895,131.1956 DOGE
# Market cap: 18,196,044,593.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8743 transactions → low activity (txn ratio = 0.5429, compared to 24h average)
# - 267416410.72 DOGE transferred
# - Average transaction fee: 0.152309 DOGE
# - 2647.9551 KB block size used
#
# [USDT]
# Price: 0.99976003 USD (stablecoin)
# Volume: 8511208.0414 USDT
# Market cap: 110,607,559,170.01 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)

# %% [markdown]
# ### K = 4

# %%
# Sliding window
K = 4
combined["all_texts_4h"] = None
for i in range(K - 1, len(combined)):
    window_texts = combined.loc[i - K + 1 : i, "all_texts"].tolist()
    combined.at[i, "all_texts_4h"] = "\n--------------------------------------------------\n".join(
        [f"=== Hour -{K - j} ===\n{text}" for j, text in enumerate(window_texts)]
    )

print(combined["all_texts_4h"].iloc[3])
# Out:
# === Hour -4 ===
# [BTC]
# Price: 57759.9547 USD
# Price change compared to last hour: -0.9957% (slight decrease)
# Volume: 11297.3861 BTC
# Market cap: 1,151,677,489,315.15 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 12908 transactions → low activity (txn ratio = 0.6669, compared to 24h average)
# - 31194 active wallets
# - 32819.8232 BTC transferred
# - Average transaction fee: 0.00007967
# - 6.4825 MB block size used
#
# [ETH]
# Price: 2947.5852 USD
# Price change compared to last hour: -0.7934% (slight decrease)
# Volume: 68867.9318 ETH
# Market cap: 364,276,973,974.75 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46619 transactions → normal activity (txn ratio = 0.9305, compared to 24h average)
# - 24704 active wallets
# - 19784.0181 ETH transferred
# - 6.8238 Gwei average gas price
# - 4,512,793,203 total gas used
#
# [SOL]
# Price: 131.4696 USD
# Price change compared to last hour: -2.3473% (significant decrease)
# Volume: 739088.8957 SOL
# Market cap: 60,292,554,289.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9021681 transactions → normal activity (txn ratio = 1.0692, compared to 24h average)
# - 280.9976 SOL total fees paid
# - Average fee per transaction: 0.00003115 SOL
#
# [DOGE]
# Price: 0.12780137 USD
# Price change compared to last hour: -2.0795% (significant decrease)
# Volume: 316,526,023.1488 DOGE
# Market cap: 18,810,287,917.28 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5188 transactions → low activity (txn ratio = 0.3307, compared to 24h average)
# - 532283108.06 DOGE transferred
# - Average transaction fee: 0.18325 DOGE
# - 1551.8828 KB block size used
#
# [USDT]
# Price: 0.99954376 USD (stablecoin)
# Volume: 9569110.3408 USDT
# Market cap: 110,656,637,832.43 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -3 ===
# [BTC]
# Price: 57109.6836 USD
# Price change compared to last hour: -1.1258% (significant decrease)
# Volume: 14704.0150 BTC
# Market cap: 1,137,037,529,278.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10342 transactions → low activity (txn ratio = 0.5521, compared to 24h average)
# - 41382 active wallets
# - 33190.3908 BTC transferred
# - Average transaction fee: 0.00011356
# - 6.4652 MB block size used
#
# [ETH]
# Price: 2905.4601 USD
# Price change compared to last hour: -1.4291% (significant decrease)
# Volume: 111094.2636 ETH
# Market cap: 359,924,892,769.84 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47028 transactions → normal activity (txn ratio = 0.9409, compared to 24h average)
# - 24418 active wallets
# - 27487.6252 ETH transferred
# - 8.8225 Gwei average gas price
# - 4,500,709,266 total gas used
#
# [SOL]
# Price: 129.6897 USD
# Price change compared to last hour: -1.3538% (significant decrease)
# Volume: 612510.1719 SOL
# Market cap: 58,680,430,144.41 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8822319 transactions → normal activity (txn ratio = 1.048, compared to 24h average)
# - 243.0346 SOL total fees paid
# - Average fee per transaction: 0.00002755 SOL
#
# [DOGE]
# Price: 0.12584491 USD
# Price change compared to last hour: -1.5309% (significant decrease)
# Volume: 305,965,050.6318 DOGE
# Market cap: 18,425,500,262.91 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13093 transactions → normal activity (txn ratio = 0.8201, compared to 24h average)
# - 233487389.16 DOGE transferred
# - Average transaction fee: 0.090736 DOGE
# - 3407.8496 KB block size used
#
# [USDT]
# Price: 0.99970228 USD (stablecoin)
# Volume: 6666103.3191 USDT
# Market cap: 110,446,577,068.57 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 57462.1227 USD
# Price change compared to last hour: +0.6171% (slight increase)
# Volume: 8106.6418 BTC
# Market cap: 1,123,568,185,488.55 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 24016 transactions → activity surge (txn ratio = 1.2741, compared to 24h average)
# - 28971 active wallets
# - 15421.4783 BTC transferred
# - Average transaction fee: 0.00004753
# - 8.0182 MB block size used
#
# [ETH]
# Price: 2917.0471 USD
# Price change compared to last hour: +0.3988% (slight increase)
# Volume: 86947.9272 ETH
# Market cap: 355,701,554,200.52 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47036 transactions → normal activity (txn ratio = 0.942, compared to 24h average)
# - 25627 active wallets
# - 59520.5448 ETH transferred
# - 7.0086 Gwei average gas price
# - 4,550,477,735 total gas used
#
# [SOL]
# Price: 129.6112 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 539810.0675 SOL
# Market cap: 58,226,094,177.67 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9235352 transactions → normal activity (txn ratio = 1.0928, compared to 24h average)
# - 238.7772 SOL total fees paid
# - Average fee per transaction: 0.00002585 SOL
#
# [DOGE]
# Price: 0.12618126 USD
# Price change compared to last hour: +0.2673% (slight increase)
# Volume: 199,895,131.1956 DOGE
# Market cap: 18,196,044,593.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8743 transactions → low activity (txn ratio = 0.5429, compared to 24h average)
# - 267416410.72 DOGE transferred
# - Average transaction fee: 0.152309 DOGE
# - 2647.9551 KB block size used
#
# [USDT]
# Price: 0.99976003 USD (stablecoin)
# Volume: 8511208.0414 USDT
# Market cap: 110,607,559,170.01 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 57441.6225 USD
# Price change compared to last hour: -0.0357% (no significant change)
# Volume: 5771.4362 BTC
# Market cap: 1,130,428,297,284.27 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 19050 transactions → normal activity (txn ratio = 1.0106, compared to 24h average)
# - 45753 active wallets
# - 33236.1482 BTC transferred
# - Average transaction fee: 0.00008654
# - 12.0817 MB block size used
#
# [ETH]
# Price: 2928.585 USD
# Price change compared to last hour: +0.3955% (slight increase)
# Volume: 45698.5247 ETH
# Market cap: 355,872,308,651.10 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47376 transactions → normal activity (txn ratio = 0.9499, compared to 24h average)
# - 25480 active wallets
# - 45184.8925 ETH transferred
# - 7.4488 Gwei average gas price
# - 4,550,407,046 total gas used
#
# [SOL]
# Price: 130.0905 USD
# Price change compared to last hour: +0.3698% (slight increase)
# Volume: 411643.4165 SOL
# Market cap: 58,055,889,781.17 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9284207 transactions → normal activity (txn ratio = 1.0997, compared to 24h average)
# - 247.4921 SOL total fees paid
# - Average fee per transaction: 0.00002666 SOL
#
# [DOGE]
# Price: 0.12643519 USD
# Price change compared to last hour: +0.2012% (slight increase)
# Volume: 107,717,798.0415 DOGE
# Market cap: 18,168,945,544.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5830 transactions → low activity (txn ratio = 0.3601, compared to 24h average)
# - 305461897.09 DOGE transferred
# - Average transaction fee: 0.172382 DOGE
# - 1836.9268 KB block size used
#
# [USDT]
# Price: 0.99962788 USD (stablecoin)
# Volume: 12571085.4063 USDT
# Market cap: 110,577,283,473.82 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)

# %%
combined
# Out:
#                timestamp                                           btc_text  \
# 0    2024-05-02 00:00:00  Price: 57759.9547 USD\nPrice change compared t...
# 1    2024-05-02 01:00:00  Price: 57109.6836 USD\nPrice change compared t...
# 2    2024-05-02 02:00:00  Price: 57462.1227 USD\nPrice change compared t...
# 3    2024-05-02 03:00:00  Price: 57441.6225 USD\nPrice change compared t...
# 4    2024-05-02 04:00:00  Price: 57386.5479 USD\nPrice change compared t...
# ...                  ...                                                ...
# 8011 2025-03-31 19:00:00  Price: 82447.4689 USD\nPrice change compared t...
# 8012 2025-03-31 20:00:00  Price: 82439.1058 USD\nPrice change compared t...
# 8013 2025-03-31 21:00:00  Price: 82567.0649 USD\nPrice change compared t...
# 8014 2025-03-31 22:00:00  Price: 82412.5917 USD\nPrice change compared t...
# 8015 2025-03-31 23:00:00  Price: 82560.4835 USD\nPrice change compared t...
#
#                                                eth_text  \
# 0     Price: 2947.5852 USD\nPrice change compared to...
# 1     Price: 2905.4601 USD\nPrice change compared to...
# 2     Price: 2917.0471 USD\nPrice change compared to...
# 3     Price: 2928.585 USD\nPrice change compared to ...
# 4     Price: 2921.4791 USD\nPrice change compared to...
# ...                                                 ...
# 8011  Price: 1827.5233 USD\nPrice change compared to...
# 8012  Price: 1819.8772 USD\nPrice change compared to...
# 8013  Price: 1824.6029 USD\nPrice change compared to...
# 8014  Price: 1824.7112 USD\nPrice change compared to...
# 8015  Price: 1822.5282 USD\nPrice change compared to...
#
#                                                sol_text  \
# 0     Price: 131.4696 USD\nPrice change compared to ...
# 1     Price: 129.6897 USD\nPrice change compared to ...
# 2     Price: 129.6112 USD\nPrice change compared to ...
# 3     Price: 130.0905 USD\nPrice change compared to ...
# 4     Price: 129.5669 USD\nPrice change compared to ...
# ...                                                 ...
# 8011  Price: 125.2499 USD\nPrice change compared to ...
# 8012  Price: 125.4111 USD\nPrice change compared to ...
# 8013  Price: 125.753 USD\nPrice change compared to l...
# 8014  Price: 125.5478 USD\nPrice change compared to ...
# 8015  Price: 124.5877 USD\nPrice change compared to ...
#
#                                               doge_text  \
# 0     Price: 0.12780137 USD\nPrice change compared t...
# 1     Price: 0.12584491 USD\nPrice change compared t...
# 2     Price: 0.12618126 USD\nPrice change compared t...
# 3     Price: 0.12643519 USD\nPrice change compared t...
# 4     Price: 0.12516028 USD\nPrice change compared t...
# ...                                                 ...
# 8011  Price: 0.16574646 USD\nPrice change compared t...
# 8012  Price: 0.16566830 USD\nPrice change compared t...
# 8013  Price: 0.16579113 USD\nPrice change compared t...
# 8014  Price: 0.16565591 USD\nPrice change compared t...
# 8015  Price: 0.16677862 USD\nPrice change compared t...
#
#                                               usdt_text  \
# 0     Price: 0.99954376 USD (stablecoin)\nVolume: 95...
# 1     Price: 0.99970228 USD (stablecoin)\nVolume: 66...
# 2     Price: 0.99976003 USD (stablecoin)\nVolume: 85...
# 3     Price: 0.99962788 USD (stablecoin)\nVolume: 12...
# 4     Price: 0.99966309 USD (stablecoin)\nVolume: 44...
# ...                                                 ...
# 8011  Price: 1.00003921 USD (stablecoin)\nVolume: 24...
# 8012  Price: 1.00000542 USD (stablecoin)\nVolume: 15...
# 8013  Price: 0.99993957 USD (stablecoin)\nVolume: 24...
# 8014  Price: 0.99992930 USD (stablecoin)\nVolume: 97...
# 8015  Price: 0.99994634 USD (stablecoin)\nVolume: 11...
#
#                                               all_texts  \
# 0     [BTC]\nPrice: 57759.9547 USD\nPrice change com...
# 1     [BTC]\nPrice: 57109.6836 USD\nPrice change com...
# 2     [BTC]\nPrice: 57462.1227 USD\nPrice change com...
# 3     [BTC]\nPrice: 57441.6225 USD\nPrice change com...
# 4     [BTC]\nPrice: 57386.5479 USD\nPrice change com...
# ...                                                 ...
# 8011  [BTC]\nPrice: 82447.4689 USD\nPrice change com...
# 8012  [BTC]\nPrice: 82439.1058 USD\nPrice change com...
# 8013  [BTC]\nPrice: 82567.0649 USD\nPrice change com...
# 8014  [BTC]\nPrice: 82412.5917 USD\nPrice change com...
# 8015  [BTC]\nPrice: 82560.4835 USD\nPrice change com...
#
#                                            all_texts_4h
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     === Hour -4 ===\n[BTC]\nPrice: 57759.9547 USD\...
# 4     === Hour -4 ===\n[BTC]\nPrice: 57109.6836 USD\...
# ...                                                 ...
# 8011  === Hour -4 ===\n[BTC]\nPrice: 83309.1402 USD\...
# 8012  === Hour -4 ===\n[BTC]\nPrice: 82697.7376 USD\...
# 8013  === Hour -4 ===\n[BTC]\nPrice: 83309.5474 USD\...
# 8014  === Hour -4 ===\n[BTC]\nPrice: 82447.4689 USD\...
# 8015  === Hour -4 ===\n[BTC]\nPrice: 82439.1058 USD\...
#
# [8016 rows x 8 columns]

# %%
all_texts_4h = combined[['timestamp', 'all_texts_4h']].copy()
all_texts_4h.head()
# Out:
#             timestamp                                       all_texts_4h
# 0 2024-05-02 00:00:00                                               None
# 1 2024-05-02 01:00:00                                               None
# 2 2024-05-02 02:00:00                                               None
# 3 2024-05-02 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 57759.9547 USD\...
# 4 2024-05-02 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 57109.6836 USD\...

# %%
all_texts_4h = all_texts_4h[3:].reset_index(drop=True)
all_texts_4h.head()
# Out:
#             timestamp                                       all_texts_4h
# 0 2024-05-02 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 57759.9547 USD\...
# 1 2024-05-02 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 57109.6836 USD\...
# 2 2024-05-02 05:00:00  === Hour -4 ===\n[BTC]\nPrice: 57462.1227 USD\...
# 3 2024-05-02 06:00:00  === Hour -4 ===\n[BTC]\nPrice: 57441.6225 USD\...
# 4 2024-05-02 07:00:00  === Hour -4 ===\n[BTC]\nPrice: 57386.5479 USD\...

# %%
print(all_texts_4h["all_texts_4h"].iloc[0])
# Out:
# === Hour -4 ===
# [BTC]
# Price: 57759.9547 USD
# Price change compared to last hour: -0.9957% (slight decrease)
# Volume: 11297.3861 BTC
# Market cap: 1,151,677,489,315.15 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 12908 transactions → low activity (txn ratio = 0.6669, compared to 24h average)
# - 31194 active wallets
# - 32819.8232 BTC transferred
# - Average transaction fee: 0.00007967
# - 6.4825 MB block size used
#
# [ETH]
# Price: 2947.5852 USD
# Price change compared to last hour: -0.7934% (slight decrease)
# Volume: 68867.9318 ETH
# Market cap: 364,276,973,974.75 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46619 transactions → normal activity (txn ratio = 0.9305, compared to 24h average)
# - 24704 active wallets
# - 19784.0181 ETH transferred
# - 6.8238 Gwei average gas price
# - 4,512,793,203 total gas used
#
# [SOL]
# Price: 131.4696 USD
# Price change compared to last hour: -2.3473% (significant decrease)
# Volume: 739088.8957 SOL
# Market cap: 60,292,554,289.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9021681 transactions → normal activity (txn ratio = 1.0692, compared to 24h average)
# - 280.9976 SOL total fees paid
# - Average fee per transaction: 0.00003115 SOL
#
# [DOGE]
# Price: 0.12780137 USD
# Price change compared to last hour: -2.0795% (significant decrease)
# Volume: 316,526,023.1488 DOGE
# Market cap: 18,810,287,917.28 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5188 transactions → low activity (txn ratio = 0.3307, compared to 24h average)
# - 532283108.06 DOGE transferred
# - Average transaction fee: 0.18325 DOGE
# - 1551.8828 KB block size used
#
# [USDT]
# Price: 0.99954376 USD (stablecoin)
# Volume: 9569110.3408 USDT
# Market cap: 110,656,637,832.43 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -3 ===
# [BTC]
# Price: 57109.6836 USD
# Price change compared to last hour: -1.1258% (significant decrease)
# Volume: 14704.0150 BTC
# Market cap: 1,137,037,529,278.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10342 transactions → low activity (txn ratio = 0.5521, compared to 24h average)
# - 41382 active wallets
# - 33190.3908 BTC transferred
# - Average transaction fee: 0.00011356
# - 6.4652 MB block size used
#
# [ETH]
# Price: 2905.4601 USD
# Price change compared to last hour: -1.4291% (significant decrease)
# Volume: 111094.2636 ETH
# Market cap: 359,924,892,769.84 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47028 transactions → normal activity (txn ratio = 0.9409, compared to 24h average)
# - 24418 active wallets
# - 27487.6252 ETH transferred
# - 8.8225 Gwei average gas price
# - 4,500,709,266 total gas used
#
# [SOL]
# Price: 129.6897 USD
# Price change compared to last hour: -1.3538% (significant decrease)
# Volume: 612510.1719 SOL
# Market cap: 58,680,430,144.41 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8822319 transactions → normal activity (txn ratio = 1.048, compared to 24h average)
# - 243.0346 SOL total fees paid
# - Average fee per transaction: 0.00002755 SOL
#
# [DOGE]
# Price: 0.12584491 USD
# Price change compared to last hour: -1.5309% (significant decrease)
# Volume: 305,965,050.6318 DOGE
# Market cap: 18,425,500,262.91 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13093 transactions → normal activity (txn ratio = 0.8201, compared to 24h average)
# - 233487389.16 DOGE transferred
# - Average transaction fee: 0.090736 DOGE
# - 3407.8496 KB block size used
#
# [USDT]
# Price: 0.99970228 USD (stablecoin)
# Volume: 6666103.3191 USDT
# Market cap: 110,446,577,068.57 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 57462.1227 USD
# Price change compared to last hour: +0.6171% (slight increase)
# Volume: 8106.6418 BTC
# Market cap: 1,123,568,185,488.55 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 24016 transactions → activity surge (txn ratio = 1.2741, compared to 24h average)
# - 28971 active wallets
# - 15421.4783 BTC transferred
# - Average transaction fee: 0.00004753
# - 8.0182 MB block size used
#
# [ETH]
# Price: 2917.0471 USD
# Price change compared to last hour: +0.3988% (slight increase)
# Volume: 86947.9272 ETH
# Market cap: 355,701,554,200.52 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47036 transactions → normal activity (txn ratio = 0.942, compared to 24h average)
# - 25627 active wallets
# - 59520.5448 ETH transferred
# - 7.0086 Gwei average gas price
# - 4,550,477,735 total gas used
#
# [SOL]
# Price: 129.6112 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 539810.0675 SOL
# Market cap: 58,226,094,177.67 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9235352 transactions → normal activity (txn ratio = 1.0928, compared to 24h average)
# - 238.7772 SOL total fees paid
# - Average fee per transaction: 0.00002585 SOL
#
# [DOGE]
# Price: 0.12618126 USD
# Price change compared to last hour: +0.2673% (slight increase)
# Volume: 199,895,131.1956 DOGE
# Market cap: 18,196,044,593.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8743 transactions → low activity (txn ratio = 0.5429, compared to 24h average)
# - 267416410.72 DOGE transferred
# - Average transaction fee: 0.152309 DOGE
# - 2647.9551 KB block size used
#
# [USDT]
# Price: 0.99976003 USD (stablecoin)
# Volume: 8511208.0414 USDT
# Market cap: 110,607,559,170.01 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 57441.6225 USD
# Price change compared to last hour: -0.0357% (no significant change)
# Volume: 5771.4362 BTC
# Market cap: 1,130,428,297,284.27 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 19050 transactions → normal activity (txn ratio = 1.0106, compared to 24h average)
# - 45753 active wallets
# - 33236.1482 BTC transferred
# - Average transaction fee: 0.00008654
# - 12.0817 MB block size used
#
# [ETH]
# Price: 2928.585 USD
# Price change compared to last hour: +0.3955% (slight increase)
# Volume: 45698.5247 ETH
# Market cap: 355,872,308,651.10 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47376 transactions → normal activity (txn ratio = 0.9499, compared to 24h average)
# - 25480 active wallets
# - 45184.8925 ETH transferred
# - 7.4488 Gwei average gas price
# - 4,550,407,046 total gas used
#
# [SOL]
# Price: 130.0905 USD
# Price change compared to last hour: +0.3698% (slight increase)
# Volume: 411643.4165 SOL
# Market cap: 58,055,889,781.17 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9284207 transactions → normal activity (txn ratio = 1.0997, compared to 24h average)
# - 247.4921 SOL total fees paid
# - Average fee per transaction: 0.00002666 SOL
#
# [DOGE]
# Price: 0.12643519 USD
# Price change compared to last hour: +0.2012% (slight increase)
# Volume: 107,717,798.0415 DOGE
# Market cap: 18,168,945,544.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5830 transactions → low activity (txn ratio = 0.3601, compared to 24h average)
# - 305461897.09 DOGE transferred
# - Average transaction fee: 0.172382 DOGE
# - 1836.9268 KB block size used
#
# [USDT]
# Price: 0.99962788 USD (stablecoin)
# Volume: 12571085.4063 USDT
# Market cap: 110,577,283,473.82 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)

# %%
all_texts_4h.to_csv("all_texts_4h.csv", index=False)

# %%
# Add Instruction to Form Prompts (Market Analyst) (Skip)
combined["prompt_4h_v1"] = combined["all_texts_4h"].apply(
    lambda x: (
        "You are a multi-asset crypto market analyst supporting a portfolio management system.\n\n"
        "Your task is to analyze the following market data to assist in making multi-asset allocation decisions across five cryptocurrencies: BTC, ETH, SOL, DOGE, and USDT.\n\n"
        "Below is a chronological snapshot of hourly market data for the last 4 hours, from oldest to newest.\n"
        "The data includes pricing, technical indicators, and on-chain activity for each asset.\n"
        "Start with a brief section **Overall Market Summary**.\n"
        "Then, under the section **Asset-Specific Analysis**, write a short analysis of market behavior for each asset (1–2 sentences).\n"
        "No other sections needed.\n"
        "Be data-driven, factual, concise, and professional. Use clear headings.\n\n"
        + x
    ) if pd.notna(x) else None
)

print(combined["prompt_4h_v1"].iloc[3])
# Out:
# You are a multi-asset crypto market analyst supporting a portfolio management system.
#
# Your task is to analyze the following market data to assist in making multi-asset allocation decisions across five cryptocurrencies: BTC, ETH, SOL, DOGE, and USDT.
#
# Below is a chronological snapshot of hourly market data for the last 4 hours, from oldest to newest.
# The data includes pricing, technical indicators, and on-chain activity for each asset.
# Start with a brief section **Overall Market Summary**.
# Then, under the section **Asset-Specific Analysis**, write a short analysis of market behavior for each asset (1–2 sentences).
# No other sections needed.
# Be data-driven, factual, concise, and professional. Use clear headings.
#
# === Hour -4 ===
# [BTC]
# Price: 57759.9547 USD
# Price change compared to last hour: -0.9957% (slight decrease)
# Volume: 11297.3861 BTC
# Market cap: 1,151,677,489,315.15 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 12908 transactions → low activity (txn ratio = 0.6669, compared to 24h average)
# - 31194 active wallets
# - 32819.8232 BTC transferred
# - Average transaction fee: 0.00007967
# - 6.4825 MB block size used
#
# [ETH]
# Price: 2947.5852 USD
# Price change compared to last hour: -0.7934% (slight decrease)
# Volume: 68867.9318 ETH
# Market cap: 364,276,973,974.75 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46619 transactions → normal activity (txn ratio = 0.9305, compared to 24h average)
# - 24704 active wallets
# - 19784.0181 ETH transferred
# - 6.8238 Gwei average gas price
# - 4,512,793,203 total gas used
#
# [SOL]
# Price: 131.4696 USD
# Price change compared to last hour: -2.3473% (significant decrease)
# Volume: 739088.8957 SOL
# Market cap: 60,292,554,289.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9021681 transactions → normal activity (txn ratio = 1.0692, compared to 24h average)
# - 280.9976 SOL total fees paid
# - Average fee per transaction: 0.00003115 SOL
#
# [DOGE]
# Price: 0.12780137 USD
# Price change compared to last hour: -2.0795% (significant decrease)
# Volume: 316,526,023.1488 DOGE
# Market cap: 18,810,287,917.28 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5188 transactions → low activity (txn ratio = 0.3307, compared to 24h average)
# - 532283108.06 DOGE transferred
# - Average transaction fee: 0.18325 DOGE
# - 1551.8828 KB block size used
#
# [USDT]
# Price: 0.99954376 USD (stablecoin)
# Volume: 9569110.3408 USDT
# Market cap: 110,656,637,832.43 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -3 ===
# [BTC]
# Price: 57109.6836 USD
# Price change compared to last hour: -1.1258% (significant decrease)
# Volume: 14704.0150 BTC
# Market cap: 1,137,037,529,278.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10342 transactions → low activity (txn ratio = 0.5521, compared to 24h average)
# - 41382 active wallets
# - 33190.3908 BTC transferred
# - Average transaction fee: 0.00011356
# - 6.4652 MB block size used
#
# [ETH]
# Price: 2905.4601 USD
# Price change compared to last hour: -1.4291% (significant decrease)
# Volume: 111094.2636 ETH
# Market cap: 359,924,892,769.84 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47028 transactions → normal activity (txn ratio = 0.9409, compared to 24h average)
# - 24418 active wallets
# - 27487.6252 ETH transferred
# - 8.8225 Gwei average gas price
# - 4,500,709,266 total gas used
#
# [SOL]
# Price: 129.6897 USD
# Price change compared to last hour: -1.3538% (significant decrease)
# Volume: 612510.1719 SOL
# Market cap: 58,680,430,144.41 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8822319 transactions → normal activity (txn ratio = 1.048, compared to 24h average)
# - 243.0346 SOL total fees paid
# - Average fee per transaction: 0.00002755 SOL
#
# [DOGE]
# Price: 0.12584491 USD
# Price change compared to last hour: -1.5309% (significant decrease)
# Volume: 305,965,050.6318 DOGE
# Market cap: 18,425,500,262.91 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13093 transactions → normal activity (txn ratio = 0.8201, compared to 24h average)
# - 233487389.16 DOGE transferred
# - Average transaction fee: 0.090736 DOGE
# - 3407.8496 KB block size used
#
# [USDT]
# Price: 0.99970228 USD (stablecoin)
# Volume: 6666103.3191 USDT
# Market cap: 110,446,577,068.57 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 57462.1227 USD
# Price change compared to last hour: +0.6171% (slight increase)
# Volume: 8106.6418 BTC
# Market cap: 1,123,568,185,488.55 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 24016 transactions → activity surge (txn ratio = 1.2741, compared to 24h average)
# - 28971 active wallets
# - 15421.4783 BTC transferred
# - Average transaction fee: 0.00004753
# - 8.0182 MB block size used
#
# [ETH]
# Price: 2917.0471 USD
# Price change compared to last hour: +0.3988% (slight increase)
# Volume: 86947.9272 ETH
# Market cap: 355,701,554,200.52 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47036 transactions → normal activity (txn ratio = 0.942, compared to 24h average)
# - 25627 active wallets
# - 59520.5448 ETH transferred
# - 7.0086 Gwei average gas price
# - 4,550,477,735 total gas used
#
# [SOL]
# Price: 129.6112 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 539810.0675 SOL
# Market cap: 58,226,094,177.67 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9235352 transactions → normal activity (txn ratio = 1.0928, compared to 24h average)
# - 238.7772 SOL total fees paid
# - Average fee per transaction: 0.00002585 SOL
#
# [DOGE]
# Price: 0.12618126 USD
# Price change compared to last hour: +0.2673% (slight increase)
# Volume: 199,895,131.1956 DOGE
# Market cap: 18,196,044,593.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8743 transactions → low activity (txn ratio = 0.5429, compared to 24h average)
# - 267416410.72 DOGE transferred
# - Average transaction fee: 0.152309 DOGE
# - 2647.9551 KB block size used
#
# [USDT]
# Price: 0.99976003 USD (stablecoin)
# Volume: 8511208.0414 USDT
# Market cap: 110,607,559,170.01 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 57441.6225 USD
# Price change compared to last hour: -0.0357% (no significant change)
# Volume: 5771.4362 BTC
# Market cap: 1,130,428,297,284.27 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 19050 transactions → normal activity (txn ratio = 1.0106, compared to 24h average)
# - 45753 active wallets
# - 33236.1482 BTC transferred
# - Average transaction fee: 0.00008654
# - 12.0817 MB block size used
#
# [ETH]
# Price: 2928.585 USD
# Price change compared to last hour: +0.3955% (slight increase)
# Volume: 45698.5247 ETH
# Market cap: 355,872,308,651.10 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47376 transactions → normal activity (txn ratio = 0.9499, compared to 24h average)
# - 25480 active wallets
# - 45184.8925 ETH transferred
# - 7.4488 Gwei average gas price
# - 4,550,407,046 total gas used
#
# [SOL]
# Price: 130.0905 USD
# Price change compared to last hour: +0.3698% (slight increase)
# Volume: 411643.4165 SOL
# Market cap: 58,055,889,781.17 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9284207 transactions → normal activity (txn ratio = 1.0997, compared to 24h average)
# - 247.4921 SOL total fees paid
# - Average fee per transaction: 0.00002666 SOL
#
# [DOGE]
# Price: 0.12643519 USD
# Price change compared to last hour: +0.2012% (slight increase)
# Volume: 107,717,798.0415 DOGE
# Market cap: 18,168,945,544.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5830 transactions → low activity (txn ratio = 0.3601, compared to 24h average)
# - 305461897.09 DOGE transferred
# - Average transaction fee: 0.172382 DOGE
# - 1836.9268 KB block size used
#
# [USDT]
# Price: 0.99962788 USD (stablecoin)
# Volume: 12571085.4063 USDT
# Market cap: 110,577,283,473.82 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)

# %%
print(combined["timestamp"].iloc[3])
# Out:
# 2024-05-02 03:00:00

# %% [markdown]
# ### K = 6

# %%
# Sliding window
K = 6
combined["all_texts_6h"] = None
for i in range(K - 1, len(combined)):
    window_texts = combined.loc[i - K + 1 : i, "all_texts"].tolist()
    combined.at[i, "all_texts_6h"] = "\n--------------------------------------------------\n".join(
        [f"=== Hour -{K - j} ===\n{text}" for j, text in enumerate(window_texts)]
    )

# %%
print(combined["all_texts_6h"].iloc[5])
# Out:
# === Hour -6 ===
# [BTC]
# Price: 57759.9547 USD
# Price change compared to last hour: -0.9957% (slight decrease)
# Volume: 11297.3861 BTC
# Market cap: 1,151,677,489,315.15 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 12908 transactions → low activity (txn ratio = 0.6669, compared to 24h average)
# - 31194 active wallets
# - 32819.8232 BTC transferred
# - Average transaction fee: 0.00007967
# - 6.4825 MB block size used
#
# [ETH]
# Price: 2947.5852 USD
# Price change compared to last hour: -0.7934% (slight decrease)
# Volume: 68867.9318 ETH
# Market cap: 364,276,973,974.75 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46619 transactions → normal activity (txn ratio = 0.9305, compared to 24h average)
# - 24704 active wallets
# - 19784.0181 ETH transferred
# - 6.8238 Gwei average gas price
# - 4,512,793,203 total gas used
#
# [SOL]
# Price: 131.4696 USD
# Price change compared to last hour: -2.3473% (significant decrease)
# Volume: 739088.8957 SOL
# Market cap: 60,292,554,289.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9021681 transactions → normal activity (txn ratio = 1.0692, compared to 24h average)
# - 280.9976 SOL total fees paid
# - Average fee per transaction: 0.00003115 SOL
#
# [DOGE]
# Price: 0.12780137 USD
# Price change compared to last hour: -2.0795% (significant decrease)
# Volume: 316,526,023.1488 DOGE
# Market cap: 18,810,287,917.28 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5188 transactions → low activity (txn ratio = 0.3307, compared to 24h average)
# - 532283108.06 DOGE transferred
# - Average transaction fee: 0.18325 DOGE
# - 1551.8828 KB block size used
#
# [USDT]
# Price: 0.99954376 USD (stablecoin)
# Volume: 9569110.3408 USDT
# Market cap: 110,656,637,832.43 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -5 ===
# [BTC]
# Price: 57109.6836 USD
# Price change compared to last hour: -1.1258% (significant decrease)
# Volume: 14704.0150 BTC
# Market cap: 1,137,037,529,278.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10342 transactions → low activity (txn ratio = 0.5521, compared to 24h average)
# - 41382 active wallets
# - 33190.3908 BTC transferred
# - Average transaction fee: 0.00011356
# - 6.4652 MB block size used
#
# [ETH]
# Price: 2905.4601 USD
# Price change compared to last hour: -1.4291% (significant decrease)
# Volume: 111094.2636 ETH
# Market cap: 359,924,892,769.84 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47028 transactions → normal activity (txn ratio = 0.9409, compared to 24h average)
# - 24418 active wallets
# - 27487.6252 ETH transferred
# - 8.8225 Gwei average gas price
# - 4,500,709,266 total gas used
#
# [SOL]
# Price: 129.6897 USD
# Price change compared to last hour: -1.3538% (significant decrease)
# Volume: 612510.1719 SOL
# Market cap: 58,680,430,144.41 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8822319 transactions → normal activity (txn ratio = 1.048, compared to 24h average)
# - 243.0346 SOL total fees paid
# - Average fee per transaction: 0.00002755 SOL
#
# [DOGE]
# Price: 0.12584491 USD
# Price change compared to last hour: -1.5309% (significant decrease)
# Volume: 305,965,050.6318 DOGE
# Market cap: 18,425,500,262.91 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13093 transactions → normal activity (txn ratio = 0.8201, compared to 24h average)
# - 233487389.16 DOGE transferred
# - Average transaction fee: 0.090736 DOGE
# - 3407.8496 KB block size used
#
# [USDT]
# Price: 0.99970228 USD (stablecoin)
# Volume: 6666103.3191 USDT
# Market cap: 110,446,577,068.57 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -4 ===
# [BTC]
# Price: 57462.1227 USD
# Price change compared to last hour: +0.6171% (slight increase)
# Volume: 8106.6418 BTC
# Market cap: 1,123,568,185,488.55 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 24016 transactions → activity surge (txn ratio = 1.2741, compared to 24h average)
# - 28971 active wallets
# - 15421.4783 BTC transferred
# - Average transaction fee: 0.00004753
# - 8.0182 MB block size used
#
# [ETH]
# Price: 2917.0471 USD
# Price change compared to last hour: +0.3988% (slight increase)
# Volume: 86947.9272 ETH
# Market cap: 355,701,554,200.52 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47036 transactions → normal activity (txn ratio = 0.942, compared to 24h average)
# - 25627 active wallets
# - 59520.5448 ETH transferred
# - 7.0086 Gwei average gas price
# - 4,550,477,735 total gas used
#
# [SOL]
# Price: 129.6112 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 539810.0675 SOL
# Market cap: 58,226,094,177.67 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9235352 transactions → normal activity (txn ratio = 1.0928, compared to 24h average)
# - 238.7772 SOL total fees paid
# - Average fee per transaction: 0.00002585 SOL
#
# [DOGE]
# Price: 0.12618126 USD
# Price change compared to last hour: +0.2673% (slight increase)
# Volume: 199,895,131.1956 DOGE
# Market cap: 18,196,044,593.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8743 transactions → low activity (txn ratio = 0.5429, compared to 24h average)
# - 267416410.72 DOGE transferred
# - Average transaction fee: 0.152309 DOGE
# - 2647.9551 KB block size used
#
# [USDT]
# Price: 0.99976003 USD (stablecoin)
# Volume: 8511208.0414 USDT
# Market cap: 110,607,559,170.01 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -3 ===
# [BTC]
# Price: 57441.6225 USD
# Price change compared to last hour: -0.0357% (no significant change)
# Volume: 5771.4362 BTC
# Market cap: 1,130,428,297,284.27 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 19050 transactions → normal activity (txn ratio = 1.0106, compared to 24h average)
# - 45753 active wallets
# - 33236.1482 BTC transferred
# - Average transaction fee: 0.00008654
# - 12.0817 MB block size used
#
# [ETH]
# Price: 2928.585 USD
# Price change compared to last hour: +0.3955% (slight increase)
# Volume: 45698.5247 ETH
# Market cap: 355,872,308,651.10 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47376 transactions → normal activity (txn ratio = 0.9499, compared to 24h average)
# - 25480 active wallets
# - 45184.8925 ETH transferred
# - 7.4488 Gwei average gas price
# - 4,550,407,046 total gas used
#
# [SOL]
# Price: 130.0905 USD
# Price change compared to last hour: +0.3698% (slight increase)
# Volume: 411643.4165 SOL
# Market cap: 58,055,889,781.17 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9284207 transactions → normal activity (txn ratio = 1.0997, compared to 24h average)
# - 247.4921 SOL total fees paid
# - Average fee per transaction: 0.00002666 SOL
#
# [DOGE]
# Price: 0.12643519 USD
# Price change compared to last hour: +0.2012% (slight increase)
# Volume: 107,717,798.0415 DOGE
# Market cap: 18,168,945,544.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5830 transactions → low activity (txn ratio = 0.3601, compared to 24h average)
# - 305461897.09 DOGE transferred
# - Average transaction fee: 0.172382 DOGE
# - 1836.9268 KB block size used
#
# [USDT]
# Price: 0.99962788 USD (stablecoin)
# Volume: 12571085.4063 USDT
# Market cap: 110,577,283,473.82 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 57386.5479 USD
# Price change compared to last hour: -0.0959% (no significant change)
# Volume: 4842.2929 BTC
# Market cap: 1,131,812,900,079.57 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13703 transactions → low activity (txn ratio = 0.7484, compared to 24h average)
# - 29676 active wallets
# - 35455.7796 BTC transferred
# - Average transaction fee: 0.00007224
# - 6.3404 MB block size used
#
# [ETH]
# Price: 2921.4791 USD
# Price change compared to last hour: -0.2426% (slight decrease)
# Volume: 44843.6898 ETH
# Market cap: 357,425,597,473.74 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 48413 transactions → normal activity (txn ratio = 0.9702, compared to 24h average)
# - 25702 active wallets
# - 35736.5768 ETH transferred
# - 6.5779 Gwei average gas price
# - 4,533,835,221 total gas used
#
# [SOL]
# Price: 129.5669 USD
# Price change compared to last hour: -0.4025% (slight decrease)
# Volume: 442239.6301 SOL
# Market cap: 58,211,846,708.44 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9015569 transactions → normal activity (txn ratio = 1.0691, compared to 24h average)
# - 230.0827 SOL total fees paid
# - Average fee per transaction: 0.00002552 SOL
#
# [DOGE]
# Price: 0.12516028 USD
# Price change compared to last hour: -1.0083% (significant decrease)
# Volume: 198,154,193.1283 DOGE
# Market cap: 18,223,617,901.76 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 31981 transactions → activity surge (txn ratio = 1.8342, compared to 24h average)
# - 402419849.08 DOGE transferred
# - Average transaction fee: 0.04979 DOGE
# - 8351.8447 KB block size used
#
# [USDT]
# Price: 0.99966309 USD (stablecoin)
# Volume: 4436367.2807 USDT
# Market cap: 110,443,278,065.80 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 57483.8332 USD
# Price change compared to last hour: +0.1695% (no significant change)
# Volume: 5998.7555 BTC
# Market cap: 1,130,831,299,501.34 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 27906 transactions → activity surge (txn ratio = 1.4705, compared to 24h average)
# - 35948 active wallets
# - 18339.111 BTC transferred
# - Average transaction fee: 0.00005398
# - 9.9944 MB block size used
#
# [ETH]
# Price: 2915.5216 USD
# Price change compared to last hour: -0.2039% (slight decrease)
# Volume: 57961.0065 ETH
# Market cap: 357,155,825,438.81 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 50972 transactions → normal activity (txn ratio = 1.0179, compared to 24h average)
# - 27529 active wallets
# - 32434.8529 ETH transferred
# - 6.8918 Gwei average gas price
# - 4,555,293,384 total gas used
#
# [SOL]
# Price: 129.589 USD
# Price change compared to last hour: +0.0171% (no significant change)
# Volume: 396723.9385 SOL
# Market cap: 58,340,081,611.71 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9084132 transactions → normal activity (txn ratio = 1.0771, compared to 24h average)
# - 200.2177 SOL total fees paid
# - Average fee per transaction: 0.00002204 SOL
#
# [DOGE]
# Price: 0.12609215 USD
# Price change compared to last hour: +0.7445% (slight increase)
# Volume: 230,295,141.0197 DOGE
# Market cap: 18,138,140,521.03 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 1678 transactions → low activity (txn ratio = 0.0965, compared to 24h average)
# - 201919304.20 DOGE transferred
# - Average transaction fee: 0.488232 DOGE
# - 501.3594 KB block size used
#
# [USDT]
# Price: 0.99985987 USD (stablecoin)
# Volume: 12760181.2852 USDT
# Market cap: 110,490,091,837.25 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)

# %%
# Add Instruction to Form Prompts
combined["prompt_6h_v1"] = combined["all_texts_6h"].apply(
    lambda x: (
        "You are a multi-asset crypto market analyst supporting a portfolio management system.\n\n"
        "Your task is to analyze the following market data to assist in making multi-asset allocation decisions across five cryptocurrencies: BTC, ETH, SOL, DOGE, and USDT.\n\n"
        "Below is a chronological snapshot of hourly market data for the last 6 hours, from oldest to newest.\n"
        "The data includes pricing, technical indicators, and on-chain activity for each asset.\n"
        "Start with a brief section **Overall Market Summary**.\n"
        "Then, under the section **Asset-Specific Analysis**, write a short analysis of market behavior for each asset (1–2 sentences).\n"
        "No other sections needed.\n"
        "Be data-driven, factual, concise, and professional. Use clear headings.\n\n"
        + x
    ) if pd.notna(x) else None
)

print(combined["prompt_6h_v1"].iloc[5])
# Out:
# You are a multi-asset crypto market analyst supporting a portfolio management system.
#
# Your task is to analyze the following market data to assist in making multi-asset allocation decisions across five cryptocurrencies: BTC, ETH, SOL, DOGE, and USDT.
#
# Below is a chronological snapshot of hourly market data for the last 6 hours, from oldest to newest.
# The data includes pricing, technical indicators, and on-chain activity for each asset.
# Start with a brief section **Overall Market Summary**.
# Then, under the section **Asset-Specific Analysis**, write a short analysis of market behavior for each asset (1–2 sentences).
# No other sections needed.
# Be data-driven, factual, concise, and professional. Use clear headings.
#
# === Hour -6 ===
# [BTC]
# Price: 57759.9547 USD
# Price change compared to last hour: -0.9957% (slight decrease)
# Volume: 11297.3861 BTC
# Market cap: 1,151,677,489,315.15 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 12908 transactions → low activity (txn ratio = 0.6669, compared to 24h average)
# - 31194 active wallets
# - 32819.8232 BTC transferred
# - Average transaction fee: 0.00007967
# - 6.4825 MB block size used
#
# [ETH]
# Price: 2947.5852 USD
# Price change compared to last hour: -0.7934% (slight decrease)
# Volume: 68867.9318 ETH
# Market cap: 364,276,973,974.75 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46619 transactions → normal activity (txn ratio = 0.9305, compared to 24h average)
# - 24704 active wallets
# - 19784.0181 ETH transferred
# - 6.8238 Gwei average gas price
# - 4,512,793,203 total gas used
#
# [SOL]
# Price: 131.4696 USD
# Price change compared to last hour: -2.3473% (significant decrease)
# Volume: 739088.8957 SOL
# Market cap: 60,292,554,289.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9021681 transactions → normal activity (txn ratio = 1.0692, compared to 24h average)
# - 280.9976 SOL total fees paid
# - Average fee per transaction: 0.00003115 SOL
#
# [DOGE]
# Price: 0.12780137 USD
# Price change compared to last hour: -2.0795% (significant decrease)
# Volume: 316,526,023.1488 DOGE
# Market cap: 18,810,287,917.28 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5188 transactions → low activity (txn ratio = 0.3307, compared to 24h average)
# - 532283108.06 DOGE transferred
# - Average transaction fee: 0.18325 DOGE
# - 1551.8828 KB block size used
#
# [USDT]
# Price: 0.99954376 USD (stablecoin)
# Volume: 9569110.3408 USDT
# Market cap: 110,656,637,832.43 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -5 ===
# [BTC]
# Price: 57109.6836 USD
# Price change compared to last hour: -1.1258% (significant decrease)
# Volume: 14704.0150 BTC
# Market cap: 1,137,037,529,278.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10342 transactions → low activity (txn ratio = 0.5521, compared to 24h average)
# - 41382 active wallets
# - 33190.3908 BTC transferred
# - Average transaction fee: 0.00011356
# - 6.4652 MB block size used
#
# [ETH]
# Price: 2905.4601 USD
# Price change compared to last hour: -1.4291% (significant decrease)
# Volume: 111094.2636 ETH
# Market cap: 359,924,892,769.84 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47028 transactions → normal activity (txn ratio = 0.9409, compared to 24h average)
# - 24418 active wallets
# - 27487.6252 ETH transferred
# - 8.8225 Gwei average gas price
# - 4,500,709,266 total gas used
#
# [SOL]
# Price: 129.6897 USD
# Price change compared to last hour: -1.3538% (significant decrease)
# Volume: 612510.1719 SOL
# Market cap: 58,680,430,144.41 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8822319 transactions → normal activity (txn ratio = 1.048, compared to 24h average)
# - 243.0346 SOL total fees paid
# - Average fee per transaction: 0.00002755 SOL
#
# [DOGE]
# Price: 0.12584491 USD
# Price change compared to last hour: -1.5309% (significant decrease)
# Volume: 305,965,050.6318 DOGE
# Market cap: 18,425,500,262.91 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13093 transactions → normal activity (txn ratio = 0.8201, compared to 24h average)
# - 233487389.16 DOGE transferred
# - Average transaction fee: 0.090736 DOGE
# - 3407.8496 KB block size used
#
# [USDT]
# Price: 0.99970228 USD (stablecoin)
# Volume: 6666103.3191 USDT
# Market cap: 110,446,577,068.57 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -4 ===
# [BTC]
# Price: 57462.1227 USD
# Price change compared to last hour: +0.6171% (slight increase)
# Volume: 8106.6418 BTC
# Market cap: 1,123,568,185,488.55 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 24016 transactions → activity surge (txn ratio = 1.2741, compared to 24h average)
# - 28971 active wallets
# - 15421.4783 BTC transferred
# - Average transaction fee: 0.00004753
# - 8.0182 MB block size used
#
# [ETH]
# Price: 2917.0471 USD
# Price change compared to last hour: +0.3988% (slight increase)
# Volume: 86947.9272 ETH
# Market cap: 355,701,554,200.52 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47036 transactions → normal activity (txn ratio = 0.942, compared to 24h average)
# - 25627 active wallets
# - 59520.5448 ETH transferred
# - 7.0086 Gwei average gas price
# - 4,550,477,735 total gas used
#
# [SOL]
# Price: 129.6112 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 539810.0675 SOL
# Market cap: 58,226,094,177.67 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9235352 transactions → normal activity (txn ratio = 1.0928, compared to 24h average)
# - 238.7772 SOL total fees paid
# - Average fee per transaction: 0.00002585 SOL
#
# [DOGE]
# Price: 0.12618126 USD
# Price change compared to last hour: +0.2673% (slight increase)
# Volume: 199,895,131.1956 DOGE
# Market cap: 18,196,044,593.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8743 transactions → low activity (txn ratio = 0.5429, compared to 24h average)
# - 267416410.72 DOGE transferred
# - Average transaction fee: 0.152309 DOGE
# - 2647.9551 KB block size used
#
# [USDT]
# Price: 0.99976003 USD (stablecoin)
# Volume: 8511208.0414 USDT
# Market cap: 110,607,559,170.01 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -3 ===
# [BTC]
# Price: 57441.6225 USD
# Price change compared to last hour: -0.0357% (no significant change)
# Volume: 5771.4362 BTC
# Market cap: 1,130,428,297,284.27 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 19050 transactions → normal activity (txn ratio = 1.0106, compared to 24h average)
# - 45753 active wallets
# - 33236.1482 BTC transferred
# - Average transaction fee: 0.00008654
# - 12.0817 MB block size used
#
# [ETH]
# Price: 2928.585 USD
# Price change compared to last hour: +0.3955% (slight increase)
# Volume: 45698.5247 ETH
# Market cap: 355,872,308,651.10 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47376 transactions → normal activity (txn ratio = 0.9499, compared to 24h average)
# - 25480 active wallets
# - 45184.8925 ETH transferred
# - 7.4488 Gwei average gas price
# - 4,550,407,046 total gas used
#
# [SOL]
# Price: 130.0905 USD
# Price change compared to last hour: +0.3698% (slight increase)
# Volume: 411643.4165 SOL
# Market cap: 58,055,889,781.17 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9284207 transactions → normal activity (txn ratio = 1.0997, compared to 24h average)
# - 247.4921 SOL total fees paid
# - Average fee per transaction: 0.00002666 SOL
#
# [DOGE]
# Price: 0.12643519 USD
# Price change compared to last hour: +0.2012% (slight increase)
# Volume: 107,717,798.0415 DOGE
# Market cap: 18,168,945,544.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5830 transactions → low activity (txn ratio = 0.3601, compared to 24h average)
# - 305461897.09 DOGE transferred
# - Average transaction fee: 0.172382 DOGE
# - 1836.9268 KB block size used
#
# [USDT]
# Price: 0.99962788 USD (stablecoin)
# Volume: 12571085.4063 USDT
# Market cap: 110,577,283,473.82 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 57386.5479 USD
# Price change compared to last hour: -0.0959% (no significant change)
# Volume: 4842.2929 BTC
# Market cap: 1,131,812,900,079.57 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13703 transactions → low activity (txn ratio = 0.7484, compared to 24h average)
# - 29676 active wallets
# - 35455.7796 BTC transferred
# - Average transaction fee: 0.00007224
# - 6.3404 MB block size used
#
# [ETH]
# Price: 2921.4791 USD
# Price change compared to last hour: -0.2426% (slight decrease)
# Volume: 44843.6898 ETH
# Market cap: 357,425,597,473.74 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 48413 transactions → normal activity (txn ratio = 0.9702, compared to 24h average)
# - 25702 active wallets
# - 35736.5768 ETH transferred
# - 6.5779 Gwei average gas price
# - 4,533,835,221 total gas used
#
# [SOL]
# Price: 129.5669 USD
# Price change compared to last hour: -0.4025% (slight decrease)
# Volume: 442239.6301 SOL
# Market cap: 58,211,846,708.44 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9015569 transactions → normal activity (txn ratio = 1.0691, compared to 24h average)
# - 230.0827 SOL total fees paid
# - Average fee per transaction: 0.00002552 SOL
#
# [DOGE]
# Price: 0.12516028 USD
# Price change compared to last hour: -1.0083% (significant decrease)
# Volume: 198,154,193.1283 DOGE
# Market cap: 18,223,617,901.76 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 31981 transactions → activity surge (txn ratio = 1.8342, compared to 24h average)
# - 402419849.08 DOGE transferred
# - Average transaction fee: 0.04979 DOGE
# - 8351.8447 KB block size used
#
# [USDT]
# Price: 0.99966309 USD (stablecoin)
# Volume: 4436367.2807 USDT
# Market cap: 110,443,278,065.80 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 57483.8332 USD
# Price change compared to last hour: +0.1695% (no significant change)
# Volume: 5998.7555 BTC
# Market cap: 1,130,831,299,501.34 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 27906 transactions → activity surge (txn ratio = 1.4705, compared to 24h average)
# - 35948 active wallets
# - 18339.111 BTC transferred
# - Average transaction fee: 0.00005398
# - 9.9944 MB block size used
#
# [ETH]
# Price: 2915.5216 USD
# Price change compared to last hour: -0.2039% (slight decrease)
# Volume: 57961.0065 ETH
# Market cap: 357,155,825,438.81 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 50972 transactions → normal activity (txn ratio = 1.0179, compared to 24h average)
# - 27529 active wallets
# - 32434.8529 ETH transferred
# - 6.8918 Gwei average gas price
# - 4,555,293,384 total gas used
#
# [SOL]
# Price: 129.589 USD
# Price change compared to last hour: +0.0171% (no significant change)
# Volume: 396723.9385 SOL
# Market cap: 58,340,081,611.71 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9084132 transactions → normal activity (txn ratio = 1.0771, compared to 24h average)
# - 200.2177 SOL total fees paid
# - Average fee per transaction: 0.00002204 SOL
#
# [DOGE]
# Price: 0.12609215 USD
# Price change compared to last hour: +0.7445% (slight increase)
# Volume: 230,295,141.0197 DOGE
# Market cap: 18,138,140,521.03 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 1678 transactions → low activity (txn ratio = 0.0965, compared to 24h average)
# - 201919304.20 DOGE transferred
# - Average transaction fee: 0.488232 DOGE
# - 501.3594 KB block size used
#
# [USDT]
# Price: 0.99985987 USD (stablecoin)
# Volume: 12760181.2852 USDT
# Market cap: 110,490,091,837.25 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)

# %% [markdown]
# # Part 4: Merge Market Data (4h) and Macro Data For Each Hour

# %%
all_data = all_texts_4h.merge(macro_text, on='timestamp')
all_data
# Out:
#                timestamp                                       all_texts_4h  \
# 0    2024-05-02 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 57759.9547 USD\...
# 1    2024-05-02 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 57109.6836 USD\...
# 2    2024-05-02 05:00:00  === Hour -4 ===\n[BTC]\nPrice: 57462.1227 USD\...
# 3    2024-05-02 06:00:00  === Hour -4 ===\n[BTC]\nPrice: 57441.6225 USD\...
# 4    2024-05-02 07:00:00  === Hour -4 ===\n[BTC]\nPrice: 57386.5479 USD\...
# ...                  ...                                                ...
# 8008 2025-03-31 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 83309.1402 USD\...
# 8009 2025-03-31 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 82697.7376 USD\...
# 8010 2025-03-31 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 83309.5474 USD\...
# 8011 2025-03-31 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 82447.4689 USD\...
# 8012 2025-03-31 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 82439.1058 USD\...
#
#                                              macro_text
# 0     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ...                                                 ...
# 8008  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8009  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8010  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8011  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8012  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [8013 rows x 3 columns]

# %%
all_data.rename(columns={'all_texts_4h': 'market_data_4h'}, inplace=True)
all_data
# Out:
#                timestamp                                     market_data_4h  \
# 0    2024-05-02 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 57759.9547 USD\...
# 1    2024-05-02 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 57109.6836 USD\...
# 2    2024-05-02 05:00:00  === Hour -4 ===\n[BTC]\nPrice: 57462.1227 USD\...
# 3    2024-05-02 06:00:00  === Hour -4 ===\n[BTC]\nPrice: 57441.6225 USD\...
# 4    2024-05-02 07:00:00  === Hour -4 ===\n[BTC]\nPrice: 57386.5479 USD\...
# ...                  ...                                                ...
# 8008 2025-03-31 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 83309.1402 USD\...
# 8009 2025-03-31 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 82697.7376 USD\...
# 8010 2025-03-31 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 83309.5474 USD\...
# 8011 2025-03-31 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 82447.4689 USD\...
# 8012 2025-03-31 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 82439.1058 USD\...
#
#                                              macro_text
# 0     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ...                                                 ...
# 8008  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8009  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8010  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8011  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 8012  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [8013 rows x 3 columns]

# %%
all_data.to_csv("all_data.csv", index=False)
# start: 2024-05-02 03:00:00
# end: 2025-03-31 23:00:00

# %%
print(all_data['macro_text'].iloc[0])
# Out:
# - 10-Year Treasury Yield (DGS10): U.S. nominal government bond yield - 4.58%
# - Crude Oil Price (WTI): Spot price in USD per barrel - $80.59
# - U.S. Dollar Index (DXY): 105.3
# - Gold Price (Spot): USD per troy ounce - $2324.43
# - S&P 500 Index: 5064.2
# - CBOE Volatility Index (VIX): 30-day implied volatility of S&P 500 index options - 14.68

# %%
print(all_data['market_data_4h'].iloc[0])
# Out:
# === Hour -4 ===
# [BTC]
# Price: 57759.9547 USD
# Price change compared to last hour: -0.9957% (slight decrease)
# Volume: 11297.3861 BTC
# Market cap: 1,151,677,489,315.15 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 12908 transactions → low activity (txn ratio = 0.6669, compared to 24h average)
# - 31194 active wallets
# - 32819.8232 BTC transferred
# - Average transaction fee: 0.00007967
# - 6.4825 MB block size used
#
# [ETH]
# Price: 2947.5852 USD
# Price change compared to last hour: -0.7934% (slight decrease)
# Volume: 68867.9318 ETH
# Market cap: 364,276,973,974.75 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46619 transactions → normal activity (txn ratio = 0.9305, compared to 24h average)
# - 24704 active wallets
# - 19784.0181 ETH transferred
# - 6.8238 Gwei average gas price
# - 4,512,793,203 total gas used
#
# [SOL]
# Price: 131.4696 USD
# Price change compared to last hour: -2.3473% (significant decrease)
# Volume: 739088.8957 SOL
# Market cap: 60,292,554,289.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9021681 transactions → normal activity (txn ratio = 1.0692, compared to 24h average)
# - 280.9976 SOL total fees paid
# - Average fee per transaction: 0.00003115 SOL
#
# [DOGE]
# Price: 0.12780137 USD
# Price change compared to last hour: -2.0795% (significant decrease)
# Volume: 316,526,023.1488 DOGE
# Market cap: 18,810,287,917.28 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5188 transactions → low activity (txn ratio = 0.3307, compared to 24h average)
# - 532283108.06 DOGE transferred
# - Average transaction fee: 0.18325 DOGE
# - 1551.8828 KB block size used
#
# [USDT]
# Price: 0.99954376 USD (stablecoin)
# Volume: 9569110.3408 USDT
# Market cap: 110,656,637,832.43 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -3 ===
# [BTC]
# Price: 57109.6836 USD
# Price change compared to last hour: -1.1258% (significant decrease)
# Volume: 14704.0150 BTC
# Market cap: 1,137,037,529,278.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10342 transactions → low activity (txn ratio = 0.5521, compared to 24h average)
# - 41382 active wallets
# - 33190.3908 BTC transferred
# - Average transaction fee: 0.00011356
# - 6.4652 MB block size used
#
# [ETH]
# Price: 2905.4601 USD
# Price change compared to last hour: -1.4291% (significant decrease)
# Volume: 111094.2636 ETH
# Market cap: 359,924,892,769.84 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47028 transactions → normal activity (txn ratio = 0.9409, compared to 24h average)
# - 24418 active wallets
# - 27487.6252 ETH transferred
# - 8.8225 Gwei average gas price
# - 4,500,709,266 total gas used
#
# [SOL]
# Price: 129.6897 USD
# Price change compared to last hour: -1.3538% (significant decrease)
# Volume: 612510.1719 SOL
# Market cap: 58,680,430,144.41 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8822319 transactions → normal activity (txn ratio = 1.048, compared to 24h average)
# - 243.0346 SOL total fees paid
# - Average fee per transaction: 0.00002755 SOL
#
# [DOGE]
# Price: 0.12584491 USD
# Price change compared to last hour: -1.5309% (significant decrease)
# Volume: 305,965,050.6318 DOGE
# Market cap: 18,425,500,262.91 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 13093 transactions → normal activity (txn ratio = 0.8201, compared to 24h average)
# - 233487389.16 DOGE transferred
# - Average transaction fee: 0.090736 DOGE
# - 3407.8496 KB block size used
#
# [USDT]
# Price: 0.99970228 USD (stablecoin)
# Volume: 6666103.3191 USDT
# Market cap: 110,446,577,068.57 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 57462.1227 USD
# Price change compared to last hour: +0.6171% (slight increase)
# Volume: 8106.6418 BTC
# Market cap: 1,123,568,185,488.55 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 24016 transactions → activity surge (txn ratio = 1.2741, compared to 24h average)
# - 28971 active wallets
# - 15421.4783 BTC transferred
# - Average transaction fee: 0.00004753
# - 8.0182 MB block size used
#
# [ETH]
# Price: 2917.0471 USD
# Price change compared to last hour: +0.3988% (slight increase)
# Volume: 86947.9272 ETH
# Market cap: 355,701,554,200.52 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47036 transactions → normal activity (txn ratio = 0.942, compared to 24h average)
# - 25627 active wallets
# - 59520.5448 ETH transferred
# - 7.0086 Gwei average gas price
# - 4,550,477,735 total gas used
#
# [SOL]
# Price: 129.6112 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 539810.0675 SOL
# Market cap: 58,226,094,177.67 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9235352 transactions → normal activity (txn ratio = 1.0928, compared to 24h average)
# - 238.7772 SOL total fees paid
# - Average fee per transaction: 0.00002585 SOL
#
# [DOGE]
# Price: 0.12618126 USD
# Price change compared to last hour: +0.2673% (slight increase)
# Volume: 199,895,131.1956 DOGE
# Market cap: 18,196,044,593.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 8743 transactions → low activity (txn ratio = 0.5429, compared to 24h average)
# - 267416410.72 DOGE transferred
# - Average transaction fee: 0.152309 DOGE
# - 2647.9551 KB block size used
#
# [USDT]
# Price: 0.99976003 USD (stablecoin)
# Volume: 8511208.0414 USDT
# Market cap: 110,607,559,170.01 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 57441.6225 USD
# Price change compared to last hour: -0.0357% (no significant change)
# Volume: 5771.4362 BTC
# Market cap: 1,130,428,297,284.27 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 19050 transactions → normal activity (txn ratio = 1.0106, compared to 24h average)
# - 45753 active wallets
# - 33236.1482 BTC transferred
# - Average transaction fee: 0.00008654
# - 12.0817 MB block size used
#
# [ETH]
# Price: 2928.585 USD
# Price change compared to last hour: +0.3955% (slight increase)
# Volume: 45698.5247 ETH
# Market cap: 355,872,308,651.10 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47376 transactions → normal activity (txn ratio = 0.9499, compared to 24h average)
# - 25480 active wallets
# - 45184.8925 ETH transferred
# - 7.4488 Gwei average gas price
# - 4,550,407,046 total gas used
#
# [SOL]
# Price: 130.0905 USD
# Price change compared to last hour: +0.3698% (slight increase)
# Volume: 411643.4165 SOL
# Market cap: 58,055,889,781.17 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 9284207 transactions → normal activity (txn ratio = 1.0997, compared to 24h average)
# - 247.4921 SOL total fees paid
# - Average fee per transaction: 0.00002666 SOL
#
# [DOGE]
# Price: 0.12643519 USD
# Price change compared to last hour: +0.2012% (slight increase)
# Volume: 107,717,798.0415 DOGE
# Market cap: 18,168,945,544.39 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 5830 transactions → low activity (txn ratio = 0.3601, compared to 24h average)
# - 305461897.09 DOGE transferred
# - Average transaction fee: 0.172382 DOGE
# - 1836.9268 KB block size used
#
# [USDT]
# Price: 0.99962788 USD (stablecoin)
# Volume: 12571085.4063 USDT
# Market cap: 110,577,283,473.82 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)

# %% [markdown]
# # Part 5:  Splitting into Various Periods (Regimes)

# %%
all_data.head()
# Out:
#             timestamp                                     market_data_4h  \
# 0 2024-05-02 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 57759.9547 USD\...
# 1 2024-05-02 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 57109.6836 USD\...
# 2 2024-05-02 05:00:00  === Hour -4 ===\n[BTC]\nPrice: 57462.1227 USD\...
# 3 2024-05-02 06:00:00  === Hour -4 ===\n[BTC]\nPrice: 57441.6225 USD\...
# 4 2024-05-02 07:00:00  === Hour -4 ===\n[BTC]\nPrice: 57386.5479 USD\...
#
#                                           macro_text
# 0  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4  - 10-Year Treasury Yield (DGS10): U.S. nominal...

# %%
bullish = all_data[(all_data['timestamp'] >= '2024-11-05 00:00:00') & (all_data['timestamp'] <= '2024-12-04 23:00:00')].copy().reset_index(drop=True)
display(bullish)
# Out:
#               timestamp                                     market_data_4h  \
# 0   2024-11-05 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 67109.7924 USD\...
# 1   2024-11-05 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 67910.7287 USD\...
# 2   2024-11-05 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 67839.6651 USD\...
# 3   2024-11-05 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 68006.8008 USD\...
# 4   2024-11-05 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 67969.5688 USD\...
# ..                  ...                                                ...
# 715 2024-12-04 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 94919.784 USD\n...
# 716 2024-12-04 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 95610.7602 USD\...
# 717 2024-12-04 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 96259.2879 USD\...
# 718 2024-12-04 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 97293.2167 USD\...
# 719 2024-12-04 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 98911.2251 USD\...
#
#                                             macro_text
# 0    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ..                                                 ...
# 715  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 716  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 717  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 718  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 719  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [720 rows x 3 columns]

# %%
bearish = all_data[(all_data['timestamp'] >= '2025-01-22 00:00:00') & (all_data['timestamp'] <= '2025-03-09 23:00:00')].copy().reset_index(drop=True)
display(bearish)
# Out:
#                timestamp                                     market_data_4h  \
# 0    2025-01-22 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 106840.0945 USD...
# 1    2025-01-22 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 106049.2196 USD...
# 2    2025-01-22 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 106188.1359 USD...
# 3    2025-01-22 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 105991.692 USD\...
# 4    2025-01-22 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 105822.8884 USD...
# ...                  ...                                                ...
# 1123 2025-03-09 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 82562.9675 USD\...
# 1124 2025-03-09 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 82421.161 USD\n...
# 1125 2025-03-09 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 82726.7141 USD\...
# 1126 2025-03-09 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 82671.2826 USD\...
# 1127 2025-03-09 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 83138.2554 USD\...
#
#                                              macro_text
# 0     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ...                                                 ...
# 1123  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1124  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1125  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1126  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1127  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [1128 rows x 3 columns]

# %%
sideways = all_data[(all_data['timestamp'] >= '2024-08-09 00:00:00') & (all_data['timestamp'] <= '2024-09-07 23:00:00')].copy().reset_index(drop=True)
display(sideways)
# Out:
#               timestamp                                     market_data_4h  \
# 0   2024-08-09 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 61159.7482 USD\...
# 1   2024-08-09 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 62358.4648 USD\...
# 2   2024-08-09 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 61734.0756 USD\...
# 3   2024-08-09 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 61257.437 USD\n...
# 4   2024-08-09 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 61443.0406 USD\...
# ..                  ...                                                ...
# 715 2024-09-07 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 54525.6008 USD\...
# 716 2024-09-07 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 54193.6441 USD\...
# 717 2024-09-07 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 54345.4161 USD\...
# 718 2024-09-07 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 54458.7186 USD\...
# 719 2024-09-07 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 54230.0669 USD\...
#
#                                             macro_text
# 0    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ..                                                 ...
# 715  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 716  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 717  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 718  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 719  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [720 rows x 3 columns]

# %%
bullish.to_csv("data/regimes/bullish/bullish_data.csv", index=False)
bearish.to_csv("data/regimes/bearish/bearish_data.csv", index=False)
sideways.to_csv("data/regimes/sideways/sideways_data.csv", index=False)

# %%
bearish.to_csv("data/regimes/bearish/bearish_data.csv", index=False)

# %% [markdown]
# # Part 6: Market Data + Macro + News -> Prompt (For Different Regimes)

# %% [markdown]
# ## A. Bullish

# %%
# Get news ready
bullish_news = bullish[['timestamp']].copy()
bullish_news['news'] = None
bullish_news
# Out:
#               timestamp  news
# 0   2024-11-05 00:00:00  None
# 1   2024-11-05 01:00:00  None
# 2   2024-11-05 02:00:00  None
# 3   2024-11-05 03:00:00  None
# 4   2024-11-05 04:00:00  None
# ..                  ...   ...
# 715 2024-12-04 19:00:00  None
# 716 2024-12-04 20:00:00  None
# 717 2024-12-04 21:00:00  None
# 718 2024-12-04 22:00:00  None
# 719 2024-12-04 23:00:00  None
#
# [720 rows x 2 columns]

# %%
from pathlib import Path
bullish_news_folder = Path("data/regimes/bullish/bullish_news_md")

for day in bullish_news['timestamp'].dt.date.unique():
    md_path = bullish_news_folder / f"{day}.md"
    if md_path.exists():
        with open(md_path, "r", encoding="utf-8") as file:
            content = file.read()
        bullish_news.loc[bullish_news['timestamp'].dt.date == day, 'news'] = content
    else:
        bullish_news.loc[bullish_news['timestamp'].dt.date == day, 'news'] = ""

# %%
bullish_news
# Out:
#               timestamp                                               news
# 0   2024-11-05 00:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 1   2024-11-05 01:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 2   2024-11-05 02:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 3   2024-11-05 03:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 4   2024-11-05 04:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# ..                  ...                                                ...
# 715 2024-12-04 19:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
# 716 2024-12-04 20:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
# 717 2024-12-04 21:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
# 718 2024-12-04 22:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
# 719 2024-12-04 23:00:00  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
#
# [720 rows x 2 columns]

# %%
bullish_news.to_csv("data/regimes/bullish/bullish_news.csv", index=False)

# %%
bullish_data = pd.read_csv("data/regimes/bullish/bullish_data.csv", parse_dates=["timestamp"])
bullish_data
# Out:
#               timestamp                                     market_data_4h  \
# 0   2024-11-05 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 67109.7924 USD\...
# 1   2024-11-05 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 67910.7287 USD\...
# 2   2024-11-05 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 67839.6651 USD\...
# 3   2024-11-05 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 68006.8008 USD\...
# 4   2024-11-05 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 67969.5688 USD\...
# ..                  ...                                                ...
# 715 2024-12-04 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 94919.784 USD\n...
# 716 2024-12-04 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 95610.7602 USD\...
# 717 2024-12-04 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 96259.2879 USD\...
# 718 2024-12-04 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 97293.2167 USD\...
# 719 2024-12-04 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 98911.2251 USD\...
#
#                                             macro_text
# 0    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ..                                                 ...
# 715  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 716  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 717  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 718  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 719  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [720 rows x 3 columns]

# %%
bullish_complete = bullish_data.merge(bullish_news, on="timestamp")
bullish_complete
# Out:
#               timestamp                                     market_data_4h  \
# 0   2024-11-05 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 67109.7924 USD\...
# 1   2024-11-05 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 67910.7287 USD\...
# 2   2024-11-05 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 67839.6651 USD\...
# 3   2024-11-05 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 68006.8008 USD\...
# 4   2024-11-05 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 67969.5688 USD\...
# ..                  ...                                                ...
# 715 2024-12-04 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 94919.784 USD\n...
# 716 2024-12-04 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 95610.7602 USD\...
# 717 2024-12-04 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 96259.2879 USD\...
# 718 2024-12-04 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 97293.2167 USD\...
# 719 2024-12-04 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 98911.2251 USD\...
#
#                                             macro_text  \
# 0    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ..                                                 ...
# 715  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 716  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 717  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 718  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 719  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
#                                                   news
# 0    **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 1    **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 2    **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 3    **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 4    **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# ..                                                 ...
# 715  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
# 716  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
# 717  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
# 718  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
# 719  **Bitcoin (BTC)**\n\n1. **Bitcoin Breaks $100K...
#
# [720 rows x 4 columns]

# %%
# Read into prompt header and tail
with open("data/prompts/prompt_header.md", "r") as file:
    prompt_header = file.read().strip()

with open("data/prompts/prompt_tail.md", "r") as file:
    prompt_tail = file.read().strip()

# %%
bullish_complete.head()
# Out:
#             timestamp                                     market_data_4h  \
# 0 2024-11-05 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 67109.7924 USD\...
# 1 2024-11-05 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 67910.7287 USD\...
# 2 2024-11-05 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 67839.6651 USD\...
# 3 2024-11-05 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 68006.8008 USD\...
# 4 2024-11-05 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 67969.5688 USD\...
#
#                                           macro_text  \
# 0  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
#                                                 news
# 0  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 1  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 2  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 3  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...
# 4  **Bitcoin (BTC)**\n\n1. **Bitcoin Surges Amid ...

# %%
# Function to build the prompt
def generate_prompt(row):
    
    macro = row['macro_text']
    market_data_4h = row['market_data_4h']
    news = row['news']

    prompt_body = f"""## Input

### 1. Macroeconomic Context
{macro}

### 2. Market Data (Past 4 Hours)
{market_data_4h}

### 3. News Summaries
{news}

### 4. Current Portfolio Status
[PORTFOLIO HERE]
"""
    return f"{prompt_header}\n\n{prompt_body}\n{prompt_tail}"

# %%
bullish_complete['prompt'] = bullish_complete.apply(generate_prompt, axis=1)

# %%
initial_portfolio_text = "- BTC: 0\n- ETH: 0\n- SOL: 0\n- DOGE: 0\n- USDT: 1,000,000\n"
bullish_complete.loc[0, 'prompt'] = bullish_complete.loc[0, 'prompt'].replace("[PORTFOLIO HERE]", initial_portfolio_text)
print(bullish_complete['prompt'][0])
# Out:
# You are an experienced multi-asset crypto trading agent operating in an hourly trading system. Your task is to make short-term asset allocation decisions across five cryptocurrencies: BTC, ETH, SOL, DOGE, and USDT. Your goal is to maximize your overall profit.
#
# For each hour, you are provided with:
#
# 1. **Macroeconomic Context:** This hour's macro indicators such as interest rates, oil prices, the U.S. dollar index, gold, the S&P 500, and volatility.
# 2. **Recent Market Data**: A chronological snapshot of the last 4 hours of market data, including pricing, technical indicators, and on-chain activity for each asset (from oldest to newest).
# 3. **Daily News Summaries**: Important news summaries for each asset, published on the same day, from sources such as CoinDesk, Cointelegraph, or Decrypt.
# 4. **Current Portfolio Status**: Your current holdings for each asset, including the quantity of BTC, ETH, SOL, DOGE, and USDT.
#
# ## Objective:
#
# Analyze both market data and news, based on your current portfolio holdings, to determine your **preferred allocation signal** for each asset in the current market environment.
#
# Output a **score between -1.0 and 1.0** for each asset, representing your directional preference and confidence level:
#
# - +1.0 = Strong buy signal / highest preference for allocating capital
# - 0.0 = Neutral / hold / no clear signal
# - -1.0 = Strong sell signal / reduce exposure (if you hold the asset)
#
# This score does **not** represent an actual trade or position size, but reflects your intent to **increase, reduce, or hold** the asset. Your scores will be interpreted and executed by a separate portfolio rebalancer, which will use them to determine actual capital allocations. Wisely select the useful information, pay more attention to **long-term trends** instead of short-term benefits. Avoid either being too conservative or changing strategies too rapidly.
#
# When assigning allocation scores, do not avaluate each asset in isolation. Consider how each asset fits into an overall portfolio strategy, including cross-asset relationships and capital rotation. For example, in bearish market conditions, you may prefer to maintain higher USDT exposure, while in bullish conditions, more capital should be shifted into other assets. Your scores should reflect the **relative attractiveness** of each asset — prioritize those most deserving of capital based on both confidence and comparative appeal.
#
# Aim to make stable, incremental changes to the portfolio. Avoid frequent, full reallocations unless the signal is strong and clearly supported by both data and news.
#
# ❗Only assign a negative score if you currently hold that asset. You cannot reduce exposure to assets that are not in your portfolio.
#
# ------
#
# ## Input
#
# ### 1. Macroeconomic Context
# - 10-Year Treasury Yield (DGS10): U.S. nominal government bond yield - 4.26%
# - Crude Oil Price (WTI): Spot price in USD per barrel - $72.26
# - U.S. Dollar Index (DXY): 103.42
# - Gold Price (Spot): USD per troy ounce - $2736.06
# - S&P 500 Index: 5782.76
# - CBOE Volatility Index (VIX): 30-day implied volatility of S&P 500 index options - 20.49
#
# ### 2. Market Data (Past 4 Hours)
# === Hour -4 ===
# [BTC]
# Price: 67109.7924 USD
# Price change compared to last hour: -0.3217% (slight decrease)
# Volume: 19439.9925 BTC
# Market cap: 1,332,688,534,366.06 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): below lower band (possible breakdown)
# On-chain activity:
# - 15188 transactions → low activity (txn ratio = 0.7672, compared to 24h average)
# - 34772 active wallets
# - 19494.3615 BTC transferred
# - Average transaction fee: 0.00001178
# - 9.514 MB block size used
#
# [ETH]
# Price: 2370.6713 USD
# Price change compared to last hour: -2.1014% (significant decrease)
# Volume: 357216.9870 ETH
# Market cap: 291,341,485,461.63 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): below lower band (possible breakdown)
# On-chain activity:
# - 48304 transactions → normal activity (txn ratio = 1.0194, compared to 24h average)
# - 20992 active wallets
# - 71791.6127 ETH transferred
# - 11.9729 Gwei average gas price
# - 4,629,470,927 total gas used
#
# [SOL]
# Price: 155.4152 USD
# Price change compared to last hour: -1.8633% (significant decrease)
# Volume: 1017030.0284 SOL
# Market cap: 74,724,201,204.00 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): below lower band (possible breakdown)
# On-chain activity:
# - 11735092 transactions → normal activity (txn ratio = 1.006, compared to 24h average)
# - 708.9183 SOL total fees paid
# - Average fee per transaction: 0.00006041 SOL
#
# [DOGE]
# Price: 0.15233192 USD
# Price change compared to last hour: -2.9512% (significant decrease)
# Volume: 535,595,057.4834 DOGE
# Market cap: 23,078,439,307.19 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 11737 transactions → low activity (txn ratio = 0.3254, compared to 24h average)
# - 615290873.47 DOGE transferred
# - Average transaction fee: 0.128368 DOGE
# - 3398.0420 KB block size used
#
# [USDT]
# Price: 0.99945488 USD (stablecoin)
# Volume: 25885671.5758 USDT
# Market cap: 120,558,307,379.99 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -3 ===
# [BTC]
# Price: 67910.7287 USD
# Price change compared to last hour: +1.1935% (significant increase)
# Volume: 8803.2781 BTC
# Market cap: 1,336,695,726,295.04 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 18577 transactions → normal activity (txn ratio = 0.9456, compared to 24h average)
# - 56814 active wallets
# - 43551.6762 BTC transferred
# - Average transaction fee: 0.00001532
# - 10.0163 MB block size used
#
# [ETH]
# Price: 2405.5955 USD
# Price change compared to last hour: +1.4732% (significant increase)
# Volume: 134585.5206 ETH
# Market cap: 285,829,149,784.90 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 47363 transactions → normal activity (txn ratio = 1.0119, compared to 24h average)
# - 20197 active wallets
# - 113655.6329 ETH transferred
# - 17.251 Gwei average gas price
# - 4,505,784,468 total gas used
#
# [SOL]
# Price: 158.0765 USD
# Price change compared to last hour: +1.7124% (significant increase)
# Volume: 553507.2988 SOL
# Market cap: 73,840,221,897.72 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 11454579 transactions → normal activity (txn ratio = 0.9821, compared to 24h average)
# - 929.8962 SOL total fees paid
# - Average fee per transaction: 0.00008118 SOL
#
# [DOGE]
# Price: 0.15800628 USD
# Price change compared to last hour: +3.7250% (significant increase)
# Volume: 399,543,653.5674 DOGE
# Market cap: 22,777,168,010.10 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 22005 transactions → low activity (txn ratio = 0.6105, compared to 24h average)
# - 659483151.45 DOGE transferred
# - Average transaction fee: 0.063576 DOGE
# - 6560.3154 KB block size used
#
# [USDT]
# Price: 0.99939165 USD (stablecoin)
# Volume: 41144769.8101 USDT
# Market cap: 120,722,990,578.62 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -2 ===
# [BTC]
# Price: 67839.6651 USD
# Price change compared to last hour: -0.1046% (no significant change)
# Volume: 6971.4705 BTC
# Market cap: 1,342,449,610,928.07 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 10188 transactions → low activity (txn ratio = 0.5354, compared to 24h average)
# - 35142 active wallets
# - 63577.2186 BTC transferred
# - Average transaction fee: 0.00001642
# - 8.0636 MB block size used
#
# [ETH]
# Price: 2397.6219 USD
# Price change compared to last hour: -0.3315% (slight decrease)
# Volume: 127861.1836 ETH
# Market cap: 289,045,682,635.59 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 46030 transactions → normal activity (txn ratio = 0.9854, compared to 24h average)
# - 21309 active wallets
# - 71494.8556 ETH transferred
# - 11.2026 Gwei average gas price
# - 4,423,840,321 total gas used
#
# [SOL]
# Price: 157.9809 USD
# Price change compared to last hour: -0.0605% (no significant change)
# Volume: 397099.0177 SOL
# Market cap: 74,249,692,864.48 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 11510291 transactions → normal activity (txn ratio = 0.9872, compared to 24h average)
# - 716.9022 SOL total fees paid
# - Average fee per transaction: 0.00006228 SOL
#
# [DOGE]
# Price: 0.15842216 USD
# Price change compared to last hour: +0.2632% (slight increase)
# Volume: 320,104,662.4244 DOGE
# Market cap: 23,097,156,673.63 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 36339 transactions → normal activity (txn ratio = 1.0148, compared to 24h average)
# - 641181242.43 DOGE transferred
# - Average transaction fee: 0.044703 DOGE
# - 10466.4531 KB block size used
#
# [USDT]
# Price: 0.99955872 USD (stablecoin)
# Volume: 9663417.1916 USDT
# Market cap: 120,405,203,250.36 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
# --------------------------------------------------
# === Hour -1 ===
# [BTC]
# Price: 68006.8008 USD
# Price change compared to last hour: +0.2464% (slight increase)
# Volume: 8352.7463 BTC
# Market cap: 1,341,197,473,461.46 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 17266 transactions → normal activity (txn ratio = 0.9175, compared to 24h average)
# - 36804 active wallets
# - 50501.9935 BTC transferred
# - Average transaction fee: 0.00001925
# - 5.7209 MB block size used
#
# [ETH]
# Price: 2400.2317 USD
# Price change compared to last hour: +0.1088% (no significant change)
# Volume: 138625.2997 ETH
# Market cap: 288,656,402,230.23 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 44719 transactions → normal activity (txn ratio = 0.9577, compared to 24h average)
# - 20914 active wallets
# - 40254.1586 ETH transferred
# - 6.6885 Gwei average gas price
# - 4,527,770,845 total gas used
#
# [SOL]
# Price: 158.576 USD
# Price change compared to last hour: +0.3767% (slight increase)
# Volume: 393737.6779 SOL
# Market cap: 74,368,798,418.98 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is below signal line → no bullish signal
# Price regime (Bollinger Bands): within band (normal range)
# On-chain activity:
# - 11896760 transactions → normal activity (txn ratio = 1.0198, compared to 24h average)
# - 715.0529 SOL total fees paid
# - Average fee per transaction: 0.00006010 SOL
#
# [DOGE]
# Price: 0.16475544 USD
# Price change compared to last hour: +3.9977% (significant increase)
# Volume: 971,480,799.0414 DOGE
# Market cap: 23,201,064,333.61 USD
# Trend signal: short MA (6h) is above long MA (24h) → buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): above upper band (possible breakout)
# On-chain activity:
# - 39144 transactions → normal activity (txn ratio = 1.0842, compared to 24h average)
# - 880052782.32 DOGE transferred
# - Average transaction fee: 0.053025 DOGE
# - 11513.4473 KB block size used
#
# [USDT]
# Price: 0.99938566 USD (stablecoin)
# Volume: 12373157.3750 USDT
# Market cap: 120,523,775,981.60 USD
# Trend signal: short MA (6h) is below long MA (24h) → no buy signal
# Momentum signal: MACD (12h vs 26h EMA) is above signal line → bullish momentum
# Price regime (Bollinger Bands): within band (normal range)
#
# ### 3. News Summaries
# **Bitcoin (BTC)**
#
# 1. **Bitcoin Surges Amid Trump’s Election Lead**
#     Bitcoin's price soared nearly 10% to $75,358 as Donald Trump approached victory in the U.S. presidential election, reflecting investor optimism for pro-crypto policies.
# 2. **Market Volatility as Election Uncertainty Looms**
#     Despite earlier gains, Bitcoin's price experienced volatility due to concerns over potential delays or disputes in the election results, highlighting market sensitivity to political developments.
#
# **Ethereum (ETH)**
#
# 1. **Ethereum Lags Behind Bitcoin and Solana**
#     Ethereum's price remained subdued compared to Bitcoin and Solana, with analysts noting decreased institutional interest and suggesting a potential target of $10,000 in the future.
# 2. **Leveraged ETH ETF Demand Rises Post-Election**
#     Following the election, demand for leveraged Ethereum ETFs increased by over 160%, indicating renewed investor interest in Ethereum's potential price appreciation.
#
# **Solana (SOL)**
#
# 1. **Solana Rallies Alongside Bitcoin**
#     Solana's price experienced significant gains in tandem with Bitcoin's rally, with data suggesting traders are targeting a $200 price point for SOL.
# 2. **Analyst Predicts Retest of $180 for Solana**
#     Market analysts indicated that if Solana maintains its current support levels, it could retest its late October highs around $180, driven by bullish momentum.
#
# **Dogecoin (DOGE)**
#
# 1. **Dogecoin Rallies on Election Optimism**
#     Dogecoin's price surged to its highest level since April, fueled by pre-election endorsements from Elon Musk and the Trump campaign, reflecting increased investor enthusiasm.
# 2. **DOGE Eyes Yearly High Amid Market Correction**
#     Despite a broader market correction, Dogecoin's price showed resilience, with analysts suggesting it could reach new yearly highs if bullish trends continue.
#
# **Tether (USDT)**
#
# 1. **Tether Mints Additional $3 Billion in USDT**
#     Tether expanded its circulating supply by minting an additional $3 billion in USDT, bringing the total to over $134 billion across various blockchains as of November 2024.
# 2. **Howard Lutnick's Ties to Tether Highlighted**
#     Reports shed light on Howard Lutnick, a Trump ally and co-chair of the transition team, whose firm manages U.S. Treasuries supporting USDT, underscoring the intersection of politics and stablecoins.
#
# ### 4. Current Portfolio Status
# - BTC: 0
# - ETH: 0
# - SOL: 0
# - DOGE: 0
# - USDT: 1,000,000
#
#
# ------
#
# ## Format your response as follows:
#
# ### Market Summary
#
# Briefly summarize overall market sentiment and important developments across assets (1–2 short paragraphs max).
#
# ### Allocation Scores (Hourly Trading Signal)
#
# List each asset and your allocation score, followed by a 1–2 sentence justification.
#
# Example:
#
# BTC: +0.7 — Strong upward momentum across price and on-chain flows. ETF-related news also supportive.
#
# ETH: -0.2 — Sideways technicals and mixed sentiment after recent sell pressure.
#
# SOL: +0.4 — Positive volume spike and DEX activity.
#
# DOGE: 0.0 — No major changes in either data or sentiment.
#
# USDT: -0.6 — Capital rotation out of stablecoins as risk appetite increases.

# %%
bullish_complete.to_csv("data/regimes/bullish/bullish_complete.csv", index=False)

# %%
bullish_prompts = bullish_complete[['timestamp', 'prompt']].copy()
bullish_prompts.to_csv("data/regimes/bullish/bullish_prompts.csv", index=False)

# %%
bullish_prompts.isna().sum()
# Out:
# timestamp    0
# prompt       0
# dtype: int64

# %% [markdown]
# ## B. Bearish

# %%
bearish
# Out:
#                timestamp                                     market_data_4h  \
# 0    2025-01-22 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 106840.0945 USD...
# 1    2025-01-22 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 106049.2196 USD...
# 2    2025-01-22 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 106188.1359 USD...
# 3    2025-01-22 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 105991.692 USD\...
# 4    2025-01-22 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 105822.8884 USD...
# ...                  ...                                                ...
# 1123 2025-03-09 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 82562.9675 USD\...
# 1124 2025-03-09 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 82421.161 USD\n...
# 1125 2025-03-09 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 82726.7141 USD\...
# 1126 2025-03-09 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 82671.2826 USD\...
# 1127 2025-03-09 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 83138.2554 USD\...
#
#                                              macro_text
# 0     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ...                                                 ...
# 1123  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1124  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1125  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1126  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1127  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [1128 rows x 3 columns]

# %%
# Get news ready
bearish_news = bearish[['timestamp']].copy()
bearish_news['news'] = None
bearish_news
# Out:
#                timestamp  news
# 0    2025-01-22 00:00:00  None
# 1    2025-01-22 01:00:00  None
# 2    2025-01-22 02:00:00  None
# 3    2025-01-22 03:00:00  None
# 4    2025-01-22 04:00:00  None
# ...                  ...   ...
# 1123 2025-03-09 19:00:00  None
# 1124 2025-03-09 20:00:00  None
# 1125 2025-03-09 21:00:00  None
# 1126 2025-03-09 22:00:00  None
# 1127 2025-03-09 23:00:00  None
#
# [1128 rows x 2 columns]

# %%
bearish_news_folder = Path("data/regimes/bearish/bearish_news_md")

for day in bearish_news['timestamp'].dt.date.unique():
    md_path = bearish_news_folder / f"{day}.md"
    if md_path.exists():
        with open(md_path, "r", encoding="utf-8") as file:
            content = file.read()
        bearish_news.loc[bearish_news['timestamp'].dt.date == day, 'news'] = content
    else:
        bearish_news.loc[bearish_news['timestamp'].dt.date == day, 'news'] = ""

# %%
bearish_news
# Out:
#                timestamp                                               news
# 0    2025-01-22 00:00:00  **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# 1    2025-01-22 01:00:00  **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# 2    2025-01-22 02:00:00  **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# 3    2025-01-22 03:00:00  **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# 4    2025-01-22 04:00:00  **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# ...                  ...                                                ...
# 1123 2025-03-09 19:00:00  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
# 1124 2025-03-09 20:00:00  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
# 1125 2025-03-09 21:00:00  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
# 1126 2025-03-09 22:00:00  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
# 1127 2025-03-09 23:00:00  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
#
# [1128 rows x 2 columns]

# %%
bearish_news.isna().sum()
# Out:
# timestamp    0
# news         0
# dtype: int64

# %%
bearish_news.to_csv("data/regimes/bearish/bearish_news.csv", index=False)

# %%
bearish_data = pd.read_csv("data/regimes/bearish/bearish_data.csv", parse_dates=["timestamp"])
bearish_data
# Out:
#                timestamp                                     market_data_4h  \
# 0    2025-01-22 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 106840.0945 USD...
# 1    2025-01-22 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 106049.2196 USD...
# 2    2025-01-22 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 106188.1359 USD...
# 3    2025-01-22 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 105991.692 USD\...
# 4    2025-01-22 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 105822.8884 USD...
# ...                  ...                                                ...
# 1123 2025-03-09 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 82562.9675 USD\...
# 1124 2025-03-09 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 82421.161 USD\n...
# 1125 2025-03-09 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 82726.7141 USD\...
# 1126 2025-03-09 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 82671.2826 USD\...
# 1127 2025-03-09 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 83138.2554 USD\...
#
#                                              macro_text
# 0     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ...                                                 ...
# 1123  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1124  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1125  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1126  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1127  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [1128 rows x 3 columns]

# %%
bearish_complete = bearish_data.merge(bearish_news, on="timestamp")
bearish_complete
# Out:
#                timestamp                                     market_data_4h  \
# 0    2025-01-22 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 106840.0945 USD...
# 1    2025-01-22 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 106049.2196 USD...
# 2    2025-01-22 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 106188.1359 USD...
# 3    2025-01-22 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 105991.692 USD\...
# 4    2025-01-22 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 105822.8884 USD...
# ...                  ...                                                ...
# 1123 2025-03-09 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 82562.9675 USD\...
# 1124 2025-03-09 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 82421.161 USD\n...
# 1125 2025-03-09 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 82726.7141 USD\...
# 1126 2025-03-09 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 82671.2826 USD\...
# 1127 2025-03-09 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 83138.2554 USD\...
#
#                                              macro_text  \
# 0     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4     - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ...                                                 ...
# 1123  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1124  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1125  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1126  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1127  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
#                                                    news
# 0     **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# 1     **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# 2     **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# 3     **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# 4     **Bitcoin (BTC)**\n\n- **Long-term holder sell...
# ...                                                 ...
# 1123  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
# 1124  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
# 1125  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
# 1126  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
# 1127  **Bitcoin (BTC)**\n\n- **Market plunges amid m...
#
# [1128 rows x 4 columns]

# %%
bearish_complete.isna().sum()
# Out:
# timestamp         0
# market_data_4h    0
# macro_text        0
# news              0
# dtype: int64

# %%
# Read into prompt header and tail
with open("data/prompts/prompt_header.md", "r") as file:
    prompt_header = file.read().strip()

with open("data/prompts/prompt_tail.md", "r") as file:
    prompt_tail = file.read().strip()
    
# Function to build the prompt
def generate_prompt(row):
    
    macro = row['macro_text']
    market_data_4h = row['market_data_4h']
    news = row['news']

    prompt_body = f"""## Input

### 1. Macroeconomic Context
{macro}

### 2. Market Data (Past 4 Hours)
{market_data_4h}

### 3. News Summaries
{news}

### 4. Current Portfolio Status
[PORTFOLIO HERE]
"""
    return f"{prompt_header}\n\n{prompt_body}\n{prompt_tail}"

bearish_complete['prompt'] = bearish_complete.apply(generate_prompt, axis=1)

# %%
bearish_complete.isna().sum()
# Out:
# timestamp         0
# market_data_4h    0
# macro_text        0
# news              0
# prompt            0
# dtype: int64

# %%
bearish_complete.to_csv("data/regimes/bearish/bearish_complete.csv", index=False)

# Only keep the timestamp and prompts
bearish_prompts = bearish_complete[['timestamp', 'prompt']].copy()
bearish_prompts.to_csv("data/regimes/bearish/bearish_prompts.csv", index=False)
bearish_prompts.isna().sum()
# Out:
# timestamp    0
# prompt       0
# dtype: int64

# %% [markdown]
# ## C. Sideways

# %%
sideways
# Out:
#               timestamp                                     market_data_4h  \
# 0   2024-08-09 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 61159.7482 USD\...
# 1   2024-08-09 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 62358.4648 USD\...
# 2   2024-08-09 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 61734.0756 USD\...
# 3   2024-08-09 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 61257.437 USD\n...
# 4   2024-08-09 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 61443.0406 USD\...
# ..                  ...                                                ...
# 715 2024-09-07 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 54525.6008 USD\...
# 716 2024-09-07 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 54193.6441 USD\...
# 717 2024-09-07 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 54345.4161 USD\...
# 718 2024-09-07 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 54458.7186 USD\...
# 719 2024-09-07 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 54230.0669 USD\...
#
#                                             macro_text
# 0    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ..                                                 ...
# 715  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 716  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 717  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 718  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 719  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [720 rows x 3 columns]

# %%
# Get news ready
sideways_news = sideways[['timestamp']].copy()
sideways_news['news'] = None
sideways_news
# Out:
#               timestamp  news
# 0   2024-08-09 00:00:00  None
# 1   2024-08-09 01:00:00  None
# 2   2024-08-09 02:00:00  None
# 3   2024-08-09 03:00:00  None
# 4   2024-08-09 04:00:00  None
# ..                  ...   ...
# 715 2024-09-07 19:00:00  None
# 716 2024-09-07 20:00:00  None
# 717 2024-09-07 21:00:00  None
# 718 2024-09-07 22:00:00  None
# 719 2024-09-07 23:00:00  None
#
# [720 rows x 2 columns]

# %%
sideways_news_folder = Path("data/regimes/sideways/sideways_news_md")

for day in sideways_news['timestamp'].dt.date.unique():
    md_path = sideways_news_folder / f"{day}.md"
    if md_path.exists():
        with open(md_path, "r", encoding="utf-8") as file:
            content = file.read()
        sideways_news.loc[sideways_news['timestamp'].dt.date == day, 'news'] = content
    else:
        sideways_news.loc[sideways_news['timestamp'].dt.date == day, 'news'] = ""

# %%
sideways_news
# Out:
#               timestamp                                               news
# 0   2024-08-09 00:00:00  **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# 1   2024-08-09 01:00:00  **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# 2   2024-08-09 02:00:00  **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# 3   2024-08-09 03:00:00  **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# 4   2024-08-09 04:00:00  **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# ..                  ...                                                ...
# 715 2024-09-07 19:00:00  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
# 716 2024-09-07 20:00:00  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
# 717 2024-09-07 21:00:00  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
# 718 2024-09-07 22:00:00  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
# 719 2024-09-07 23:00:00  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
#
# [720 rows x 2 columns]

# %%
sideways_news.isna().sum()
# Out:
# timestamp    0
# news         0
# dtype: int64

# %%
sideways_news.to_csv("data/regimes/sideways/sideways_news.csv", index=False)

# %%
sideways_data = pd.read_csv("data/regimes/sideways/sideways_data.csv", parse_dates=["timestamp"])
sideways_data
# Out:
#               timestamp                                     market_data_4h  \
# 0   2024-08-09 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 61159.7482 USD\...
# 1   2024-08-09 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 62358.4648 USD\...
# 2   2024-08-09 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 61734.0756 USD\...
# 3   2024-08-09 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 61257.437 USD\n...
# 4   2024-08-09 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 61443.0406 USD\...
# ..                  ...                                                ...
# 715 2024-09-07 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 54525.6008 USD\...
# 716 2024-09-07 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 54193.6441 USD\...
# 717 2024-09-07 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 54345.4161 USD\...
# 718 2024-09-07 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 54458.7186 USD\...
# 719 2024-09-07 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 54230.0669 USD\...
#
#                                             macro_text
# 0    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ..                                                 ...
# 715  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 716  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 717  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 718  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 719  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
# [720 rows x 3 columns]

# %%
sideways_complete = sideways_data.merge(sideways_news, on="timestamp")
sideways_complete
# Out:
#               timestamp                                     market_data_4h  \
# 0   2024-08-09 00:00:00  === Hour -4 ===\n[BTC]\nPrice: 61159.7482 USD\...
# 1   2024-08-09 01:00:00  === Hour -4 ===\n[BTC]\nPrice: 62358.4648 USD\...
# 2   2024-08-09 02:00:00  === Hour -4 ===\n[BTC]\nPrice: 61734.0756 USD\...
# 3   2024-08-09 03:00:00  === Hour -4 ===\n[BTC]\nPrice: 61257.437 USD\n...
# 4   2024-08-09 04:00:00  === Hour -4 ===\n[BTC]\nPrice: 61443.0406 USD\...
# ..                  ...                                                ...
# 715 2024-09-07 19:00:00  === Hour -4 ===\n[BTC]\nPrice: 54525.6008 USD\...
# 716 2024-09-07 20:00:00  === Hour -4 ===\n[BTC]\nPrice: 54193.6441 USD\...
# 717 2024-09-07 21:00:00  === Hour -4 ===\n[BTC]\nPrice: 54345.4161 USD\...
# 718 2024-09-07 22:00:00  === Hour -4 ===\n[BTC]\nPrice: 54458.7186 USD\...
# 719 2024-09-07 23:00:00  === Hour -4 ===\n[BTC]\nPrice: 54230.0669 USD\...
#
#                                             macro_text  \
# 0    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 1    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 2    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 3    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 4    - 10-Year Treasury Yield (DGS10): U.S. nominal...
# ..                                                 ...
# 715  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 716  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 717  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 718  - 10-Year Treasury Yield (DGS10): U.S. nominal...
# 719  - 10-Year Treasury Yield (DGS10): U.S. nominal...
#
#                                                   news
# 0    **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# 1    **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# 2    **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# 3    **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# 4    **Bitcoin (BTC)**\n\n- **BTC jumps nearly 12% ...
# ..                                                 ...
# 715  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
# 716  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
# 717  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
# 718  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
# 719  **Bitcoin (BTC)**\n\n- **Volatile swing tied t...
#
# [720 rows x 4 columns]

# %%
sideways_complete.isna().sum()
# Out:
# timestamp         0
# market_data_4h    0
# macro_text        0
# news              0
# dtype: int64

# %%
# Read into prompt header and tail
with open("data/prompts/prompt_header.md", "r") as file:
    prompt_header = file.read().strip()

with open("data/prompts/prompt_tail.md", "r") as file:
    prompt_tail = file.read().strip()
    
# Function to build the prompt
def generate_prompt(row):
    
    macro = row['macro_text']
    market_data_4h = row['market_data_4h']
    news = row['news']

    prompt_body = f"""## Input

### 1. Macroeconomic Context
{macro}

### 2. Market Data (Past 4 Hours)
{market_data_4h}

### 3. News Summaries
{news}

### 4. Current Portfolio Status
[PORTFOLIO HERE]
"""
    return f"{prompt_header}\n\n{prompt_body}\n{prompt_tail}"

sideways_complete['prompt'] = sideways_complete.apply(generate_prompt, axis=1)

# %%
sideways_complete.isna().sum()
# Out:
# timestamp         0
# market_data_4h    0
# macro_text        0
# news              0
# prompt            0
# dtype: int64

# %%
sideways_complete.to_csv("data/regimes/sideways/sideways_complete.csv", index=False)

# Only keep the timestamp and prompts
sideways_prompts = sideways_complete[['timestamp', 'prompt']].copy()
sideways_prompts.to_csv("data/regimes/sideways/sideways_prompts.csv", index=False)
sideways_prompts.isna().sum()
# Out:
# timestamp    0
# prompt       0
# dtype: int64

# %%
# Out:
# timestamp    0
# prompt       0
# dtype: int64
